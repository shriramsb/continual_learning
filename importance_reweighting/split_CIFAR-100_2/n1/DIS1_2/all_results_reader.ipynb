# %%
import sys
sys.path.append('../../../')

# %%
import numpy as np
import math

# %matplotlib inline
import matplotlib.pyplot as plt

import pickle
import argparse
import time
import itertools
from copy import deepcopy
    
# %load_ext autoreload
# %autoreload 2

# %%
with open('summaries_5_0/all_results', 'rb') as f:
    all_results = pickle.load(f)

# %%
task = 19
for k, v in all_results[task].items():
    plt.plot(np.concatenate((np.mean(np.array(v[0]['val_acc'])[-1:], axis=0), np.mean(np.array(v[1]['val_acc'])[-1:], axis=0))))
    plt.show()
    break

# %%
nrows = 5
ncols = 4
f, axarr = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, sharey=True)
for i in range(nrows):
    for j in range(ncols):
        axarr[i, j].plot(np.concatenate((np.array(v[0]['val_acc'])[i * ncols + j], np.array(v[1]['val_acc'])[i * ncols + j])))
