# %%
import sys
sys.path.append('../../../')

# %%
import numpy as np
import math

# %matplotlib inline
import matplotlib.pyplot as plt

import pickle
import argparse
import time
import itertools
from copy import deepcopy
    
# %load_ext autoreload
# %autoreload 2

# %%
with open('summaries_5_0/all_results', 'rb') as f:
    all_results = pickle.load(f)

# %%
task = 3
for k, v in all_results[task].items():
    plt.plot(np.mean(np.array(v['val_acc']), axis=0))
    plt.show()
    break

# %%
task = 19
for k, v in all_results[task].items():
    print(np.array(v['val_acc'])[19, :])
    break
