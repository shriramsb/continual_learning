# %%
import sys
sys.path.append('../../../')

# %%
import numpy as np
import math

# %matplotlib inline
import matplotlib.pyplot as plt

import pickle
import argparse
import time
import itertools
from copy import deepcopy
    
# %load_ext autoreload
# %autoreload 2

# %%
with open('summaries_99_1_0/all_results', 'rb') as f:
    all_results = pickle.load(f)

# %%
task = 1
for k, v in all_results[task].items():
    plt.plot(np.mean(np.array(v[0]['val_acc'][0:1]), axis=0), color='b')
    plt.plot(np.mean(np.array(v[0]['val_acc'][1:2]), axis=0), color='g')
    plt.show()
    break

# %%
task = 19
for k, v in all_results[task].items():
    print(np.array(v['val_acc'])[19, :])
    break
