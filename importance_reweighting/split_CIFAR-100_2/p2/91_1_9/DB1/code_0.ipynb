# %% [markdown]
# ### Import and init GPU

# %%
from IPython.display import Audio

# %%
import sys
sys.path.append('../../../../')

# %%
import numpy as np
import math

# %matplotlib inline
import matplotlib.pyplot as plt

import pickle
import argparse
import time
import itertools
from copy import deepcopy
import tensorflow as tf

from tuner import HyperparameterTuner
from tuner import MyTask

use_tpu = False
use_gpu = True

if use_tpu:
    from tensorflow.contrib import tpu
    from tensorflow.contrib.cluster_resolver import TPUClusterResolver

if use_gpu:
    import os
    
# %load_ext autoreload
# %autoreload 2

# %%
if use_gpu:
    os.environ['CUDA_VISIBLE_DEVICES'] = '2'
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True

# %%
if use_tpu:
    tpu_cluster = TPUClusterResolver(tpu=[tpu_name]).get_master()
    sess = tf.Session(tpu_cluster)
    sess.run(tpu.initialize_system())
elif use_gpu:
    sess = tf.Session(config=config)
else:
    sess = tf.Session()

# %%
from resnet import Network

# %%
network = Network()

# %%
task_home = ''
if use_tpu:
    pass
#     task_home = 'gs://continual_learning/permMNIST_EWC/'
else:
    task_home = '../../../../../'

cur_dir = './'
checkpoint_path = cur_dir + 'checkpoints_0/'
summaries_path = cur_dir + 'summaries_0/'
data_path = task_home + 'cifar-100-python/'
split_path = './split.txt' 
if use_tpu:
    tpu_name = 'gectpu'
    
BATCH_SIZE = 128

# %% [markdown]
# ### Dataset loading functions

# %%
label_smooth_param = 0

def splitDataset(dataset, dataset_split, seed):
    np.random.seed(seed)
    task_list = []
    train_labels = np.argmax(dataset.train.labels, axis=1)
    validation_labels = np.argmax(dataset.validation.labels, axis=1)
    test_labels = np.argmax(dataset.test.labels, axis=1)
    for i in range(len(dataset_split)):
        cur_train_indices = [False] * dataset.train.images.shape[0]
        cur_validation_indices = [False] * dataset.validation.images.shape[0]
        cur_test_indices = [False] * dataset.test.images.shape[0]
        for j in range(len(dataset_split[i])):
            cur_train_indices = np.logical_or(cur_train_indices, (train_labels == dataset_split[i][j]))
            cur_validation_indices = np.logical_or(cur_validation_indices, (validation_labels == dataset_split[i][j]))
            cur_test_indices = np.logical_or(cur_test_indices, (test_labels == dataset_split[i][j]))

        task = deepcopy(dataset)
        task.train.images = task.train.images[cur_train_indices]
        task.train.labels = task.train.labels[cur_train_indices]
        task.validation.images = task.validation.images[cur_validation_indices]
        task.validation.labels = task.validation.labels[cur_validation_indices]
        task.test.images = task.test.images[cur_test_indices]
        task.test.labels = task.test.labels[cur_test_indices]
        task = MyTask(task)
        task_list.append(task)

    return task_list
    
def smoothLabels(dataset):
    train_labels = dataset.train.labels
    train_labels_argmax = np.argmax(train_labels, axis=1)
    train_labels = train_labels + label_smooth_param / (train_labels.shape[1] - 1)
    train_labels[range(train_labels.shape[0]), train_labels_argmax] = 1 - label_smooth_param
    dataset.train._labels = train_labels

class TempDataset(object):
    def __init__(self):
        self.images = None
        self.labels = None
    
class TempTask(object):
    def __init__(self):
        self.train = TempDataset()
        self.validation = TempDataset()
        self.test = TempDataset()
    
    
def readDatasets():
    num_class = 100
    labels_list = list(range(num_class))
    seed = 0
    np.random.seed(seed)
    np.random.shuffle(labels_list)
    split = []
    task_weights = []
    
    split = [labels_list[ : 91]]
    task_weights = [0.91]
    for single_label in labels_list[91 : ]:
        split.append([single_label])
        task_weights.append(0.01)
    num_tasks = len(split)
    
    with open(data_path + 'train', 'rb') as f:
        f_train_data = pickle.load(f, encoding='bytes')
        
    with open(data_path + 'test', 'rb') as f:
        f_test_data = pickle.load(f, encoding='bytes')
        
    cifar_100 = TempTask()
    temp_train_labels = np.array(f_train_data[b'fine_labels'], dtype=np.int32)
    temp_test_labels = np.array(f_test_data[b'fine_labels'], dtype=np.int32)
    f_train_data[b'fine_labels'] = np.zeros((temp_train_labels.shape[0], num_class))
    (f_train_data[b'fine_labels'])[range(temp_train_labels.shape[0]), temp_train_labels] = 1
    f_test_data[b'fine_labels'] = np.zeros((temp_test_labels.shape[0], num_class))
    (f_test_data[b'fine_labels'])[range(temp_test_labels.shape[0]), temp_test_labels] = 1
    f_train_data[b'data'] = np.reshape(f_train_data[b'data'], (-1, 3, 32, 32))
    f_test_data[b'data'] = np.reshape(f_test_data[b'data'], (-1, 3, 32, 32))
    f_train_data[b'data'] = np.transpose(f_train_data[b'data'], (0, 2, 3, 1))
    f_test_data[b'data'] = np.transpose(f_test_data[b'data'], (0, 2, 3, 1))
    
    tr_data = f_train_data[b'data']
    te_data = f_test_data[b'data']
    # normalizing data
    avg = np.mean(tr_data, axis=(0, 1, 2))
    std = np.std(tr_data, axis=(0, 1, 2))
    
    f_train_data[b'data'] = (tr_data - avg) / std
    f_test_data[b'data'] = (te_data - avg) / std
    
    seed = 0
    np.random.seed(0)
    shuffle_train_perm = np.random.permutation(f_train_data[b'data'].shape[0])
    f_train_data[b'data'] = f_train_data[b'data'][shuffle_train_perm]
    f_train_data[b'fine_labels'] = f_train_data[b'fine_labels'][shuffle_train_perm]
    
    num_val_per_class = 20
    
    for i in range(num_class):
        pos = (np.argmax(f_train_data[b'fine_labels'], axis=1) == i)
        
        if (i == 0):
            cifar_100.validation.images = (f_train_data[b'data'][pos])[0 : num_val_per_class]
            cifar_100.validation.labels = (f_train_data[b'fine_labels'][pos])[0 : num_val_per_class]

            cifar_100.train.images = (f_train_data[b'data'][pos])[num_val_per_class : ]
            cifar_100.train.labels = (f_train_data[b'fine_labels'][pos])[num_val_per_class : ]
        else:
            cifar_100.validation.images = np.concatenate((cifar_100.validation.images, (f_train_data[b'data'][pos])[0 : num_val_per_class]))
            cifar_100.validation.labels = np.concatenate((cifar_100.validation.labels, (f_train_data[b'fine_labels'][pos])[0 : num_val_per_class]))

            cifar_100.train.images = np.concatenate((cifar_100.train.images, (f_train_data[b'data'][pos])[num_val_per_class : ]))
            cifar_100.train.labels = np.concatenate((cifar_100.train.labels, (f_train_data[b'fine_labels'][pos])[num_val_per_class : ]))
        
    cifar_100.test.images = f_test_data[b'data']
    cifar_100.test.labels = f_test_data[b'fine_labels']
    
    shuffle_train_perm = np.random.permutation(cifar_100.train.images.shape[0])
    cifar_100.train.images = cifar_100.train.images[shuffle_train_perm]
    cifar_100.train.labels = cifar_100.train.labels[shuffle_train_perm]
    
    if (label_smooth_param != 0):
        smoothLabels(cifar_100)
        
    task_list = splitDataset(cifar_100, split, seed)
    return split, num_tasks, task_weights, task_list

# %% [markdown]
# ### Create tuner object and train!!

# %%
input_shape = (32, 32, 3)
output_shape = (100, )

# %%
tuner = HyperparameterTuner(sess=sess, network=network, 
                            input_shape=input_shape, output_shape=output_shape,
                            checkpoint_path=checkpoint_path, summaries_path=summaries_path, 
                            readDatasets=readDatasets, load_best_hparams=False)
# Out:
# WARNING:tensorflow:From ../../../../classifiers.py:100: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
tuner.setPerExampleAppend(1.0)
tuner.updateTunerHparams({'mask_softmax' : True})

# %% [markdown]
# ### Training each task separately

# %%
t = 0
learning_rates = [1e-1]
momentums = [0.9]
regs = [0.0001]
dropout_input_probs = [1.0]
dropout_hidden_probs = [0.9]
prod = list(itertools.product(regs, dropout_input_probs, dropout_hidden_probs, momentums, learning_rates))
hparams = []
for hparams_tuple in prod:
    cur_dict = {}
    cur_dict['reg'] = hparams_tuple[0]
    cur_dict['dropout_input_prob'] = hparams_tuple[2]
    cur_dict['dropout_hidden_prob'] = hparams_tuple[2]
    cur_dict['momentum'] = hparams_tuple[3]
    cur_dict['learning_rate'] = hparams_tuple[4]
    hparams.append(cur_dict)

tuner.hparams_list[t] = hparams

# %%
num_epochs = 160
num_updates = math.ceil(tuner.task_list[t].train.images.shape[0] / BATCH_SIZE) * num_epochs
tuner.print_every = 10

# %%
start_time = time.time()
best_avg, best_hparams = tuner.tuneOnTask(t, BATCH_SIZE, 
                                          save_weights=False, 
                                          num_updates=num_updates, verbose=True, 
                                          random_crop_flip=True)
print("time taken : %d" % (time.time() - start_time))
sound_file = '/mnt/a99/d0/shriramsb/code/Alan Walker - Alone.mp3'
Audio(sound_file, autoplay=True)

# %%
import math
plt.rcParams['figure.figsize'] = [10, 5]
lr_scatter = ([math.log10(h['learning_rate']) for h in hparams])
dropout_scatter = [h['dropout_hidden_prob'] for h in hparams]
colors = []
for i in range(len(hparams)):
    cur_hparam_tuple = tuner.hparamsDictToTuple(hparams[i], tuner.tuner_hparams)
    colors.append(tuner.results_list[t][cur_hparam_tuple]['best_avg'])
    
marker_size = 100
fig, ax = plt.subplots()
plt.scatter(lr_scatter, dropout_scatter, marker_size, c=colors, edgecolors='black')
plt.colorbar()
for i in range(len(lr_scatter)):
    ax.annotate(str('%0.4f' % (colors[i], )), (lr_scatter[i], dropout_scatter[i]))
plt.show()

# %%
plt.rcParams['figure.figsize'] = [10, 10]
best_hparams_tuple = tuner.hparamsDictToTuple(hparams[0], tuner.tuner_hparams)
cur_res = tuner.results_list[t][best_hparams_tuple]
x = np.arange(0, cur_res['total_updates'], cur_res['updates_per_epoch'])
cur_best_avg = cur_res['best_avg']
cur_best_avg_updates = cur_res['best_avg_updates']
updates_per_epoch = cur_res['updates_per_epoch']
# print("dropout: %f, fisher_multiplier: %e, lr: %e" % (k[0], k[1], k[2]))
print("cur_best_avg: %e, num_updates: %d" % (cur_best_avg, cur_best_avg_updates))
print("best val_acc: %s" % (str(np.array(cur_res['val_acc'])[:, (cur_best_avg_updates // updates_per_epoch - 1) // tuner.eval_frequency])))
# plt.plot(cur_res['loss_with_penalty'], color='g')
plt.plot(cur_res['loss'], color='m')
plt.plot(x, cur_res['val_loss'][-1], color='b')
plt.show()
# plt.ylim(ymin=0.9)
plt.plot(cur_res['val_acc'][0], color='b', )
# plt.plot(cur_res['val_acc'][1], color='g')

plt.show()

# %%
# print(best_avg, best_hparams)
VALIDATION_BATCH_SIZE = 128
print(tuner.validationAccuracy(t, VALIDATION_BATCH_SIZE, restore_model=False))

# %%
t = 1
learning_rates = [1e-1]
momentums = [0.9]
regs = [0.0001]
dropout_input_probs = [1.0]
dropout_hidden_probs = [0.9]
prod = list(itertools.product(regs, dropout_input_probs, dropout_hidden_probs, momentums, learning_rates))
hparams = []
for hparams_tuple in prod:
    cur_dict = {}
    cur_dict['reg'] = hparams_tuple[0]
    cur_dict['dropout_input_prob'] = hparams_tuple[2]
    cur_dict['dropout_hidden_prob'] = hparams_tuple[2]
    cur_dict['momentum'] = hparams_tuple[3]
    cur_dict['learning_rate'] = hparams_tuple[4]
    hparams.append(cur_dict)

tuner.hparams_list[t] = hparams

# %%
num_epochs = 160
num_updates = math.ceil(tuner.task_list[t].train.images.shape[0] / BATCH_SIZE) * num_epochs
tuner.print_every = 10

# %%
start_time = time.time()
best_avg, best_hparams = tuner.tuneOnTask(t, BATCH_SIZE, 
                                          save_weights=False, 
                                          num_updates=num_updates, verbose=True, 
                                          random_crop_flip=True)
print("time taken : %d" % (time.time() - start_time))
sound_file = '/mnt/a99/d0/shriramsb/code/Alan Walker - Alone.mp3'
Audio(sound_file, autoplay=True)

# %%
import math
plt.rcParams['figure.figsize'] = [10, 5]
lr_scatter = ([math.log10(h['learning_rate']) for h in hparams])
dropout_scatter = [h['dropout_hidden_prob'] for h in hparams]
colors = []
for i in range(len(hparams)):
    cur_hparam_tuple = tuner.hparamsDictToTuple(hparams[i], tuner.tuner_hparams)
    colors.append(tuner.results_list[t][cur_hparam_tuple]['best_avg'])
    
marker_size = 100
fig, ax = plt.subplots()
plt.scatter(lr_scatter, dropout_scatter, marker_size, c=colors, edgecolors='black')
plt.colorbar()
for i in range(len(lr_scatter)):
    ax.annotate(str('%0.4f' % (colors[i], )), (lr_scatter[i], dropout_scatter[i]))
plt.show()

# %%
plt.rcParams['figure.figsize'] = [10, 10]
best_hparams_tuple = tuner.hparamsDictToTuple(hparams[0], tuner.tuner_hparams)
cur_res = tuner.results_list[t][best_hparams_tuple]
x = np.arange(0, cur_res['total_updates'], cur_res['updates_per_epoch'])
cur_best_avg = cur_res['best_avg']
cur_best_avg_updates = cur_res['best_avg_updates']
updates_per_epoch = cur_res['updates_per_epoch']
# print("dropout: %f, fisher_multiplier: %e, lr: %e" % (k[0], k[1], k[2]))
print("cur_best_avg: %e, num_updates: %d" % (cur_best_avg, cur_best_avg_updates))
print("best val_acc: %s" % (str(np.array(cur_res['val_acc'])[:, (cur_best_avg_updates // updates_per_epoch - 1) // tuner.eval_frequency])))
# plt.plot(cur_res['loss_with_penalty'], color='g')
plt.plot(cur_res['loss'], color='m')
plt.plot(x, cur_res['val_loss'][-1], color='b')
plt.show()
# plt.ylim(ymin=0.9)
plt.plot(cur_res['val_acc'][0], color='b', )
plt.plot(cur_res['val_acc'][1], color='g')

plt.show()

# %% [markdown]
# ### Train tasks together

# %%
t = 0
learning_rates = [(((49, 1e-1), (63, 1e-1 / 5), 1e-1 / (5 * 5)), (1e-1, ))]
momentums = [0.9]
regs = [0.00001]
dropout_input_probs = [1.0]
dropout_hidden_probs = [0.9]
prod = list(itertools.product(regs, dropout_input_probs, dropout_hidden_probs, momentums, learning_rates))
hparams = []
for hparams_tuple in prod:
    cur_dict = {}
    cur_dict['reg'] = hparams_tuple[0]
    cur_dict['dropout_input_prob'] = hparams_tuple[2]
    cur_dict['dropout_hidden_prob'] = hparams_tuple[2]
    cur_dict['momentum'] = hparams_tuple[3]
    cur_dict['learning_rate'] = hparams_tuple[4]
    hparams.append(cur_dict)
    
for i in range(0, t + 1):
    tuner.hparams_list[i] = hparams

# %%
num_hparams = len(hparams)
num_epochs = 70
num_updates = math.ceil(tuner.task_list[t].train.images.shape[0] / BATCH_SIZE) * num_epochs
tuner.print_every = 100

# %%
best_avg, best_hparams_index = tuner.tuneTasksInRange(0, t, BATCH_SIZE, num_hparams, 
                                                        num_updates=num_updates, verbose=True, 
                                                        random_crop_flip=True, 
                                                        equal_weights=True)
# Out:
# Training with T=None,alpha=0.0,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.0,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0
# epoch: 0, iter: 100/342, loss: 3.952404, accuracy: 0.054688
# epoch: 0, iter: 200/342, loss: 3.717833, accuracy: 0.140625
# epoch: 0, iter: 300/342, loss: 3.579928, accuracy: 0.132812
# epoch: 1, iter: 0/342, validation accuracies: [0.11593407], average train loss: 3.997124, average train accuracy: 0.073077
# epoch: 1, iter: 58/342, loss: 3.508539, accuracy: 0.171875
# epoch: 1, iter: 158/342, loss: 3.405050, accuracy: 0.179688
# epoch: 1, iter: 258/342, loss: 3.413889, accuracy: 0.132812
# epoch: 2, iter: 0/342, validation accuracies: [0.19175824], average train loss: 3.452638, average train accuracy: 0.158808
# epoch: 2, iter: 16/342, loss: 3.160216, accuracy: 0.226562
# epoch: 2, iter: 116/342, loss: 3.038945, accuracy: 0.234375
# epoch: 2, iter: 216/342, loss: 3.098219, accuracy: 0.234375
# epoch: 2, iter: 316/342, loss: 3.075995, accuracy: 0.226562
# epoch: 3, iter: 0/342, validation accuracies: [0.23681318], average train loss: 3.051153, average train accuracy: 0.235449
# epoch: 3, iter: 74/342, loss: 3.001448, accuracy: 0.203125
# epoch: 3, iter: 174/342, loss: 2.510130, accuracy: 0.335938
# epoch: 3, iter: 274/342, loss: 2.298132, accuracy: 0.359375
# epoch: 4, iter: 0/342, validation accuracies: [0.30549451], average train loss: 2.680618, average train accuracy: 0.304916
# epoch: 4, iter: 32/342, loss: 2.809757, accuracy: 0.234375
# epoch: 4, iter: 132/342, loss: 2.155550, accuracy: 0.460938
# epoch: 4, iter: 232/342, loss: 2.454610, accuracy: 0.343750
# epoch: 4, iter: 332/342, loss: 2.159312, accuracy: 0.343750
# epoch: 5, iter: 0/342, validation accuracies: [0.36153846], average train loss: 2.389320, average train accuracy: 0.368215
# epoch: 5, iter: 90/342, loss: 2.435648, accuracy: 0.335938
# epoch: 5, iter: 190/342, loss: 2.155827, accuracy: 0.429688
# epoch: 5, iter: 290/342, loss: 2.222444, accuracy: 0.375000
# epoch: 6, iter: 0/342, validation accuracies: [0.38021978], average train loss: 2.163182, average train accuracy: 0.414314
# epoch: 6, iter: 48/342, loss: 1.973190, accuracy: 0.492188
# epoch: 6, iter: 148/342, loss: 1.906131, accuracy: 0.507812
# epoch: 6, iter: 248/342, loss: 1.941946, accuracy: 0.492188
# epoch: 7, iter: 0/342, validation accuracies: [0.42197802], average train loss: 1.960479, average train accuracy: 0.459887
# epoch: 7, iter: 6/342, loss: 1.748402, accuracy: 0.492188
# epoch: 7, iter: 106/342, loss: 2.206402, accuracy: 0.445312
# epoch: 7, iter: 206/342, loss: 1.903908, accuracy: 0.476562
# epoch: 7, iter: 306/342, loss: 1.630391, accuracy: 0.539062
# epoch: 8, iter: 0/342, validation accuracies: [0.44505494], average train loss: 1.826500, average train accuracy: 0.492142
# epoch: 8, iter: 64/342, loss: 1.735860, accuracy: 0.562500
# epoch: 8, iter: 164/342, loss: 1.708241, accuracy: 0.523438
# epoch: 8, iter: 264/342, loss: 1.472753, accuracy: 0.554688
# epoch: 9, iter: 0/342, validation accuracies: [0.47197802], average train loss: 1.699520, average train accuracy: 0.524488
# epoch: 9, iter: 22/342, loss: 1.527604, accuracy: 0.648438
# epoch: 9, iter: 122/342, loss: 1.427659, accuracy: 0.539062
# epoch: 9, iter: 222/342, loss: 1.368938, accuracy: 0.593750
# epoch: 9, iter: 322/342, loss: 1.578775, accuracy: 0.570312
# epoch: 10, iter: 0/342, validation accuracies: [0.4934066], average train loss: 1.602120, average train accuracy: 0.548406
# epoch: 10, iter: 80/342, loss: 1.507968, accuracy: 0.562500
# epoch: 10, iter: 180/342, loss: 1.566889, accuracy: 0.554688
# epoch: 10, iter: 280/342, loss: 1.449616, accuracy: 0.578125
# epoch: 11, iter: 0/342, validation accuracies: [0.50989012], average train loss: 1.513576, average train accuracy: 0.570724
# epoch: 11, iter: 38/342, loss: 1.491721, accuracy: 0.593750
# epoch: 11, iter: 138/342, loss: 1.261975, accuracy: 0.640625
# epoch: 11, iter: 238/342, loss: 1.503834, accuracy: 0.554688
# epoch: 11, iter: 338/342, loss: 1.538463, accuracy: 0.609375
# epoch: 12, iter: 0/342, validation accuracies: [0.51098902], average train loss: 1.446530, average train accuracy: 0.586509
# epoch: 12, iter: 96/342, loss: 1.462557, accuracy: 0.546875
# epoch: 12, iter: 196/342, loss: 1.431785, accuracy: 0.570312
# epoch: 12, iter: 296/342, loss: 1.411866, accuracy: 0.609375
# epoch: 13, iter: 0/342, validation accuracies: [0.55384615], average train loss: 1.380465, average train accuracy: 0.608758
# epoch: 13, iter: 54/342, loss: 1.303347, accuracy: 0.656250
# epoch: 13, iter: 154/342, loss: 1.352677, accuracy: 0.593750
# epoch: 13, iter: 254/342, loss: 1.062617, accuracy: 0.632812
# epoch: 14, iter: 0/342, validation accuracies: [0.5434066], average train loss: 1.315295, average train accuracy: 0.619358
# epoch: 14, iter: 12/342, loss: 1.297687, accuracy: 0.562500
# epoch: 14, iter: 112/342, loss: 1.359414, accuracy: 0.593750
# epoch: 14, iter: 212/342, loss: 1.371024, accuracy: 0.617188
# epoch: 14, iter: 312/342, loss: 1.371472, accuracy: 0.570312
# epoch: 15, iter: 0/342, validation accuracies: [0.54945055], average train loss: 1.277507, average train accuracy: 0.629249
# epoch: 15, iter: 70/342, loss: 1.271156, accuracy: 0.625000
# epoch: 15, iter: 170/342, loss: 1.186698, accuracy: 0.695312
# epoch: 15, iter: 270/342, loss: 1.468243, accuracy: 0.585938
# epoch: 16, iter: 0/342, validation accuracies: [0.54999999], average train loss: 1.224387, average train accuracy: 0.643686
# epoch: 16, iter: 28/342, loss: 1.039342, accuracy: 0.687500
# epoch: 16, iter: 128/342, loss: 1.419375, accuracy: 0.578125
# epoch: 16, iter: 228/342, loss: 1.167038, accuracy: 0.648438
# epoch: 16, iter: 328/342, loss: 1.254553, accuracy: 0.617188
# epoch: 17, iter: 0/342, validation accuracies: [0.54120878], average train loss: 1.169662, average train accuracy: 0.657438
# epoch: 17, iter: 86/342, loss: 1.307313, accuracy: 0.617188
# epoch: 17, iter: 186/342, loss: 1.173251, accuracy: 0.671875
# epoch: 17, iter: 286/342, loss: 1.078029, accuracy: 0.671875
# epoch: 18, iter: 0/342, validation accuracies: [0.54835164], average train loss: 1.145974, average train accuracy: 0.665616
# epoch: 18, iter: 44/342, loss: 1.046318, accuracy: 0.703125
# epoch: 18, iter: 144/342, loss: 1.161635, accuracy: 0.640625
# epoch: 18, iter: 244/342, loss: 1.071749, accuracy: 0.664062
# epoch: 19, iter: 0/342, validation accuracies: [0.56208791], average train loss: 1.130334, average train accuracy: 0.668266
# epoch: 19, iter: 2/342, loss: 1.074507, accuracy: 0.687500
# epoch: 19, iter: 102/342, loss: 1.179708, accuracy: 0.648438
# epoch: 19, iter: 202/342, loss: 0.907354, accuracy: 0.757812
# epoch: 19, iter: 302/342, loss: 0.876935, accuracy: 0.726562
# epoch: 20, iter: 0/342, validation accuracies: [0.55714285], average train loss: 1.077344, average train accuracy: 0.681401
# epoch: 20, iter: 60/342, loss: 1.101111, accuracy: 0.671875
# epoch: 20, iter: 160/342, loss: 0.815125, accuracy: 0.742188
# epoch: 20, iter: 260/342, loss: 1.165676, accuracy: 0.648438
# epoch: 21, iter: 0/342, validation accuracies: [0.57142857], average train loss: 1.030860, average train accuracy: 0.696158
# epoch: 21, iter: 18/342, loss: 0.924523, accuracy: 0.742188
# epoch: 21, iter: 118/342, loss: 0.857606, accuracy: 0.765625
# epoch: 21, iter: 218/342, loss: 1.015152, accuracy: 0.757812
# epoch: 21, iter: 318/342, loss: 1.078130, accuracy: 0.695312
# epoch: 22, iter: 0/342, validation accuracies: [0.57967034], average train loss: 1.028399, average train accuracy: 0.695701
# epoch: 22, iter: 76/342, loss: 1.292840, accuracy: 0.679688
# epoch: 22, iter: 176/342, loss: 0.924449, accuracy: 0.742188
# epoch: 22, iter: 276/342, loss: 0.930191, accuracy: 0.718750
# epoch: 23, iter: 0/342, validation accuracies: [0.60439561], average train loss: 0.995923, average train accuracy: 0.700955
# epoch: 23, iter: 34/342, loss: 1.075861, accuracy: 0.687500
# epoch: 23, iter: 134/342, loss: 1.171236, accuracy: 0.648438
# epoch: 23, iter: 234/342, loss: 0.945785, accuracy: 0.718750
# epoch: 23, iter: 334/342, loss: 1.031968, accuracy: 0.703125
# epoch: 24, iter: 0/342, validation accuracies: [0.59120879], average train loss: 0.976953, average train accuracy: 0.709361
# epoch: 24, iter: 92/342, loss: 1.101937, accuracy: 0.671875
# epoch: 24, iter: 192/342, loss: 0.962034, accuracy: 0.687500
# epoch: 24, iter: 292/342, loss: 0.866778, accuracy: 0.726562
# epoch: 25, iter: 0/342, validation accuracies: [0.55879122], average train loss: 0.933357, average train accuracy: 0.718841
# epoch: 25, iter: 50/342, loss: 0.901033, accuracy: 0.703125
# epoch: 25, iter: 150/342, loss: 0.841786, accuracy: 0.703125
# epoch: 25, iter: 250/342, loss: 1.177395, accuracy: 0.679688
# epoch: 26, iter: 0/342, validation accuracies: [0.59230769], average train loss: 0.918690, average train accuracy: 0.723159
# epoch: 26, iter: 8/342, loss: 0.766311, accuracy: 0.757812
# epoch: 26, iter: 108/342, loss: 0.750028, accuracy: 0.765625
# epoch: 26, iter: 208/342, loss: 0.886194, accuracy: 0.718750
# epoch: 26, iter: 308/342, loss: 0.742012, accuracy: 0.765625
# epoch: 27, iter: 0/342, validation accuracies: [0.58516483], average train loss: 0.884694, average train accuracy: 0.733530
# epoch: 27, iter: 66/342, loss: 0.868346, accuracy: 0.750000
# epoch: 27, iter: 166/342, loss: 0.922596, accuracy: 0.765625
# epoch: 27, iter: 266/342, loss: 0.903732, accuracy: 0.726562
# epoch: 28, iter: 0/342, validation accuracies: [0.59395605], average train loss: 0.867280, average train accuracy: 0.738967
# epoch: 28, iter: 24/342, loss: 0.868106, accuracy: 0.757812
# epoch: 28, iter: 124/342, loss: 0.895705, accuracy: 0.718750
# epoch: 28, iter: 224/342, loss: 0.840475, accuracy: 0.757812
# epoch: 28, iter: 324/342, loss: 0.814173, accuracy: 0.781250
# epoch: 29, iter: 0/342, validation accuracies: [0.60494505], average train loss: 0.843178, average train accuracy: 0.745934
# epoch: 29, iter: 82/342, loss: 0.949581, accuracy: 0.718750
# epoch: 29, iter: 182/342, loss: 0.926139, accuracy: 0.718750
# epoch: 29, iter: 282/342, loss: 0.728628, accuracy: 0.765625
# epoch: 30, iter: 0/342, validation accuracies: [0.59065933], average train loss: 0.823722, average train accuracy: 0.749726
# epoch: 30, iter: 40/342, loss: 0.797447, accuracy: 0.718750
# epoch: 30, iter: 140/342, loss: 1.075193, accuracy: 0.734375
# epoch: 30, iter: 240/342, loss: 1.097564, accuracy: 0.679688
# epoch: 30, iter: 340/342, loss: 0.745047, accuracy: 0.765625
# epoch: 31, iter: 0/342, validation accuracies: [0.60659342], average train loss: 0.813386, average train accuracy: 0.751713
# epoch: 31, iter: 98/342, loss: 0.879598, accuracy: 0.734375
# epoch: 31, iter: 198/342, loss: 0.928399, accuracy: 0.742188
# epoch: 31, iter: 298/342, loss: 0.656446, accuracy: 0.781250
# epoch: 32, iter: 0/342, validation accuracies: [0.6054945], average train loss: 0.792852, average train accuracy: 0.756647
# epoch: 32, iter: 56/342, loss: 0.879471, accuracy: 0.765625
# epoch: 32, iter: 156/342, loss: 0.936862, accuracy: 0.710938
# epoch: 32, iter: 256/342, loss: 0.836234, accuracy: 0.757812
# epoch: 33, iter: 0/342, validation accuracies: [0.59010989], average train loss: 0.766769, average train accuracy: 0.765511
# epoch: 33, iter: 14/342, loss: 0.856487, accuracy: 0.726562
# epoch: 33, iter: 114/342, loss: 0.820499, accuracy: 0.742188
# epoch: 33, iter: 214/342, loss: 0.798246, accuracy: 0.750000
# epoch: 33, iter: 314/342, loss: 0.668519, accuracy: 0.835938
# epoch: 34, iter: 0/342, validation accuracies: [0.61318681], average train loss: 0.758459, average train accuracy: 0.769097
# epoch: 34, iter: 72/342, loss: 0.565725, accuracy: 0.843750
# epoch: 34, iter: 172/342, loss: 0.574014, accuracy: 0.812500
# epoch: 34, iter: 272/342, loss: 0.777314, accuracy: 0.773438
# epoch: 35, iter: 0/342, validation accuracies: [0.60219782], average train loss: 0.732363, average train accuracy: 0.772684
# epoch: 35, iter: 30/342, loss: 0.710240, accuracy: 0.804688
# epoch: 35, iter: 130/342, loss: 0.676982, accuracy: 0.789062
# epoch: 35, iter: 230/342, loss: 0.859021, accuracy: 0.757812
# epoch: 35, iter: 330/342, loss: 0.455947, accuracy: 0.875000
# epoch: 36, iter: 0/342, validation accuracies: [0.59615385], average train loss: 0.723364, average train accuracy: 0.778737
# epoch: 36, iter: 88/342, loss: 0.711376, accuracy: 0.773438
# epoch: 36, iter: 188/342, loss: 0.862035, accuracy: 0.710938
# epoch: 36, iter: 288/342, loss: 0.823977, accuracy: 0.734375
# epoch: 37, iter: 0/342, validation accuracies: [0.62252747], average train loss: 0.708334, average train accuracy: 0.782072
# epoch: 37, iter: 46/342, loss: 0.878042, accuracy: 0.742188
# epoch: 37, iter: 146/342, loss: 0.758309, accuracy: 0.789062
# epoch: 37, iter: 246/342, loss: 0.733360, accuracy: 0.742188
# epoch: 38, iter: 0/342, validation accuracies: [0.5989011], average train loss: 0.694637, average train accuracy: 0.785910
# epoch: 38, iter: 4/342, loss: 0.512109, accuracy: 0.812500
# epoch: 38, iter: 104/342, loss: 0.565739, accuracy: 0.843750
# epoch: 38, iter: 204/342, loss: 0.784603, accuracy: 0.757812
# epoch: 38, iter: 304/342, loss: 0.583923, accuracy: 0.898438
# epoch: 39, iter: 0/342, validation accuracies: [0.59835164], average train loss: 0.677521, average train accuracy: 0.792535
# epoch: 39, iter: 62/342, loss: 0.676085, accuracy: 0.796875
# epoch: 39, iter: 162/342, loss: 0.599347, accuracy: 0.812500
# epoch: 39, iter: 262/342, loss: 0.694651, accuracy: 0.773438
# epoch: 40, iter: 0/342, validation accuracies: [0.59560439], average train loss: 0.667857, average train accuracy: 0.790913
# epoch: 40, iter: 20/342, loss: 0.506285, accuracy: 0.828125
# epoch: 40, iter: 120/342, loss: 0.859161, accuracy: 0.757812
# epoch: 40, iter: 220/342, loss: 0.557586, accuracy: 0.804688
# epoch: 40, iter: 320/342, loss: 0.469198, accuracy: 0.859375
# epoch: 41, iter: 0/342, validation accuracies: [0.62087913], average train loss: 0.657854, average train accuracy: 0.793768
# epoch: 41, iter: 78/342, loss: 0.679621, accuracy: 0.773438
# epoch: 41, iter: 178/342, loss: 0.678887, accuracy: 0.734375
# epoch: 41, iter: 278/342, loss: 0.660357, accuracy: 0.789062
# epoch: 42, iter: 0/342, validation accuracies: [0.60549451], average train loss: 0.640908, average train accuracy: 0.799753
# epoch: 42, iter: 36/342, loss: 0.648034, accuracy: 0.796875
# epoch: 42, iter: 136/342, loss: 0.460224, accuracy: 0.835938
# epoch: 42, iter: 236/342, loss: 0.763130, accuracy: 0.773438
# epoch: 42, iter: 336/342, loss: 0.642425, accuracy: 0.781250
# epoch: 43, iter: 0/342, validation accuracies: [0.61043957], average train loss: 0.626133, average train accuracy: 0.804779
# epoch: 43, iter: 94/342, loss: 0.561275, accuracy: 0.828125
# epoch: 43, iter: 194/342, loss: 0.663784, accuracy: 0.804688
# epoch: 43, iter: 294/342, loss: 0.500973, accuracy: 0.851562
# epoch: 44, iter: 0/342, validation accuracies: [0.60274725], average train loss: 0.595712, average train accuracy: 0.811746
# epoch: 44, iter: 52/342, loss: 0.713359, accuracy: 0.820312
# epoch: 44, iter: 152/342, loss: 0.652235, accuracy: 0.789062
# epoch: 44, iter: 252/342, loss: 0.531789, accuracy: 0.828125
# epoch: 45, iter: 0/342, validation accuracies: [0.6153846], average train loss: 0.610620, average train accuracy: 0.808594
# epoch: 45, iter: 10/342, loss: 0.601373, accuracy: 0.820312
# epoch: 45, iter: 110/342, loss: 0.621107, accuracy: 0.812500
# epoch: 45, iter: 210/342, loss: 0.411084, accuracy: 0.882812
# epoch: 45, iter: 310/342, loss: 0.518441, accuracy: 0.820312
# epoch: 46, iter: 0/342, validation accuracies: [0.60604397], average train loss: 0.593262, average train accuracy: 0.811700
# epoch: 46, iter: 68/342, loss: 0.584482, accuracy: 0.812500
# epoch: 46, iter: 168/342, loss: 0.639271, accuracy: 0.804688
# epoch: 46, iter: 268/342, loss: 0.382793, accuracy: 0.882812
# epoch: 47, iter: 0/342, validation accuracies: [0.61263737], average train loss: 0.571415, average train accuracy: 0.821455
# epoch: 47, iter: 26/342, loss: 0.608873, accuracy: 0.828125
# epoch: 47, iter: 126/342, loss: 0.588518, accuracy: 0.828125
# epoch: 47, iter: 226/342, loss: 0.629327, accuracy: 0.781250
# epoch: 47, iter: 326/342, loss: 0.362906, accuracy: 0.906250
# epoch: 48, iter: 0/342, validation accuracies: [0.60329669], average train loss: 0.565196, average train accuracy: 0.824242
# epoch: 48, iter: 84/342, loss: 0.497334, accuracy: 0.867188
# epoch: 48, iter: 184/342, loss: 0.595687, accuracy: 0.812500
# epoch: 48, iter: 284/342, loss: 0.543545, accuracy: 0.820312
# epoch: 49, iter: 0/342, validation accuracies: [0.62087912], average train loss: 0.552119, average train accuracy: 0.827188
# epoch: 49, iter: 42/342, loss: 0.477761, accuracy: 0.843750
# epoch: 49, iter: 142/342, loss: 0.383800, accuracy: 0.882812
# epoch: 49, iter: 242/342, loss: 0.408480, accuracy: 0.875000
# epoch: 50, iter: 0/342, validation accuracies: [0.6489011], average train loss: 0.420427, average train accuracy: 0.871276
# epoch: 50, iter: 0/342, loss: 0.223567, accuracy: 0.921875
# epoch: 50, iter: 100/342, loss: 0.508505, accuracy: 0.804688
# epoch: 50, iter: 200/342, loss: 0.451786, accuracy: 0.875000
# epoch: 50, iter: 300/342, loss: 0.288275, accuracy: 0.898438
# epoch: 51, iter: 0/342, validation accuracies: [0.65329671], average train loss: 0.364282, average train accuracy: 0.887770
# epoch: 51, iter: 58/342, loss: 0.395462, accuracy: 0.898438
# epoch: 51, iter: 158/342, loss: 0.233014, accuracy: 0.945312
# epoch: 51, iter: 258/342, loss: 0.344085, accuracy: 0.867188
# epoch: 52, iter: 0/342, validation accuracies: [0.65384615], average train loss: 0.344877, average train accuracy: 0.894394
# epoch: 52, iter: 16/342, loss: 0.338242, accuracy: 0.906250
# epoch: 52, iter: 116/342, loss: 0.268715, accuracy: 0.921875
# epoch: 52, iter: 216/342, loss: 0.363004, accuracy: 0.914062
# epoch: 52, iter: 316/342, loss: 0.406230, accuracy: 0.843750
# epoch: 53, iter: 0/342, validation accuracies: [0.65054945], average train loss: 0.320158, average train accuracy: 0.901065
# epoch: 53, iter: 74/342, loss: 0.277674, accuracy: 0.914062
# epoch: 53, iter: 174/342, loss: 0.400671, accuracy: 0.882812
# epoch: 53, iter: 274/342, loss: 0.327379, accuracy: 0.898438
# epoch: 54, iter: 0/342, validation accuracies: [0.65494506], average train loss: 0.308158, average train accuracy: 0.904011
# epoch: 54, iter: 32/342, loss: 0.274526, accuracy: 0.921875
# epoch: 54, iter: 132/342, loss: 0.209065, accuracy: 0.945312
# epoch: 54, iter: 232/342, loss: 0.429151, accuracy: 0.875000
# epoch: 54, iter: 332/342, loss: 0.232159, accuracy: 0.945312
# epoch: 55, iter: 0/342, validation accuracies: [0.65714287], average train loss: 0.299953, average train accuracy: 0.906547
# epoch: 55, iter: 90/342, loss: 0.347706, accuracy: 0.898438
# epoch: 55, iter: 190/342, loss: 0.233032, accuracy: 0.929688
# epoch: 55, iter: 290/342, loss: 0.322913, accuracy: 0.898438
# epoch: 56, iter: 0/342, validation accuracies: [0.66373627], average train loss: 0.294026, average train accuracy: 0.908557
# epoch: 56, iter: 48/342, loss: 0.317292, accuracy: 0.898438
# epoch: 56, iter: 148/342, loss: 0.314822, accuracy: 0.898438
# epoch: 56, iter: 248/342, loss: 0.304198, accuracy: 0.890625
# epoch: 57, iter: 0/342, validation accuracies: [0.65494506], average train loss: 0.284883, average train accuracy: 0.910522
# epoch: 57, iter: 6/342, loss: 0.296547, accuracy: 0.906250
# epoch: 57, iter: 106/342, loss: 0.185938, accuracy: 0.960938
# epoch: 57, iter: 206/342, loss: 0.276164, accuracy: 0.906250
# epoch: 57, iter: 306/342, loss: 0.233755, accuracy: 0.929688
# epoch: 58, iter: 0/342, validation accuracies: [0.65384617], average train loss: 0.279734, average train accuracy: 0.913743
# epoch: 58, iter: 64/342, loss: 0.334542, accuracy: 0.875000
# epoch: 58, iter: 164/342, loss: 0.252648, accuracy: 0.914062
# epoch: 58, iter: 264/342, loss: 0.243585, accuracy: 0.929688
# epoch: 59, iter: 0/342, validation accuracies: [0.66043956], average train loss: 0.276024, average train accuracy: 0.914839
# epoch: 59, iter: 22/342, loss: 0.145193, accuracy: 0.953125
# epoch: 59, iter: 122/342, loss: 0.143495, accuracy: 0.968750
# epoch: 59, iter: 222/342, loss: 0.337342, accuracy: 0.890625
# epoch: 59, iter: 322/342, loss: 0.189836, accuracy: 0.945312
# epoch: 60, iter: 0/342, validation accuracies: [0.65274726], average train loss: 0.269326, average train accuracy: 0.915867
# epoch: 60, iter: 80/342, loss: 0.344500, accuracy: 0.867188
# epoch: 60, iter: 180/342, loss: 0.239924, accuracy: 0.914062
# epoch: 60, iter: 280/342, loss: 0.202767, accuracy: 0.921875
# epoch: 61, iter: 0/342, validation accuracies: [0.65989011], average train loss: 0.269092, average train accuracy: 0.914793
# epoch: 61, iter: 38/342, loss: 0.202764, accuracy: 0.953125
# epoch: 61, iter: 138/342, loss: 0.286104, accuracy: 0.890625
# epoch: 61, iter: 238/342, loss: 0.211681, accuracy: 0.921875
# epoch: 61, iter: 338/342, loss: 0.153253, accuracy: 0.953125
# epoch: 62, iter: 0/342, validation accuracies: [0.65769231], average train loss: 0.256862, average train accuracy: 0.919636
# epoch: 62, iter: 96/342, loss: 0.207162, accuracy: 0.945312
# epoch: 62, iter: 196/342, loss: 0.258328, accuracy: 0.929688
# epoch: 62, iter: 296/342, loss: 0.286838, accuracy: 0.898438
# epoch: 63, iter: 0/342, validation accuracies: [0.65769231], average train loss: 0.255649, average train accuracy: 0.919362
# epoch: 63, iter: 54/342, loss: 0.174850, accuracy: 0.953125
# epoch: 63, iter: 154/342, loss: 0.268034, accuracy: 0.890625
# epoch: 63, iter: 254/342, loss: 0.211186, accuracy: 0.921875
# epoch: 64, iter: 0/342, validation accuracies: [0.66428572], average train loss: 0.240053, average train accuracy: 0.924639
# epoch: 64, iter: 12/342, loss: 0.186693, accuracy: 0.960938
# epoch: 64, iter: 112/342, loss: 0.222832, accuracy: 0.914062
# epoch: 64, iter: 212/342, loss: 0.166783, accuracy: 0.937500
# epoch: 64, iter: 312/342, loss: 0.246807, accuracy: 0.937500
# epoch: 65, iter: 0/342, validation accuracies: [0.65989011], average train loss: 0.230211, average train accuracy: 0.929825
# epoch: 65, iter: 70/342, loss: 0.272557, accuracy: 0.921875
# epoch: 65, iter: 170/342, loss: 0.294810, accuracy: 0.921875
# epoch: 65, iter: 270/342, loss: 0.271673, accuracy: 0.914062
# epoch: 66, iter: 0/342, validation accuracies: [0.66318682], average train loss: 0.225203, average train accuracy: 0.931287
# epoch: 66, iter: 28/342, loss: 0.174163, accuracy: 0.929688
# epoch: 66, iter: 128/342, loss: 0.211920, accuracy: 0.953125
# epoch: 66, iter: 228/342, loss: 0.277023, accuracy: 0.906250
# epoch: 66, iter: 328/342, loss: 0.136838, accuracy: 0.953125
# epoch: 67, iter: 0/342, validation accuracies: [0.66208792], average train loss: 0.223553, average train accuracy: 0.931538
# epoch: 67, iter: 86/342, loss: 0.176026, accuracy: 0.945312
# epoch: 67, iter: 186/342, loss: 0.117565, accuracy: 0.968750
# epoch: 67, iter: 286/342, loss: 0.251862, accuracy: 0.921875
# epoch: 68, iter: 0/342, validation accuracies: [0.6587912], average train loss: 0.220112, average train accuracy: 0.933388
# epoch: 68, iter: 44/342, loss: 0.192503, accuracy: 0.937500
# epoch: 68, iter: 144/342, loss: 0.145872, accuracy: 0.968750
# epoch: 68, iter: 244/342, loss: 0.277759, accuracy: 0.890625
# epoch: 69, iter: 0/342, validation accuracies: [0.65989011], average train loss: 0.217985, average train accuracy: 0.935101
# epoch: 69, iter: 2/342, loss: 0.142641, accuracy: 0.960938
# epoch: 69, iter: 102/342, loss: 0.126262, accuracy: 0.960938
# epoch: 69, iter: 202/342, loss: 0.166232, accuracy: 0.953125
# epoch: 69, iter: 302/342, loss: 0.231612, accuracy: 0.921875
# epoch: 70, iter: 0/342, validation accuracies: [0.65879122], average train loss: 0.222339, average train accuracy: 0.931012
# epochs: 70.000000, final train loss: 0.209487, validation accuracies: [0.65879122]
# best epochs: 64.000000, best_avg: 0.664286, validation accuracies: [0.66428572]
# saving model dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0 at time step 23940
# calculating penultimate output...
# time taken: %f 5.024698972702026
# saving penultimate output...

# %%
plt.rcParams['figure.figsize'] = [10, 10]
best_hparams_tuple = tuner.hparamsDictToTuple(hparams[0], tuner.tuner_hparams)
cur_res = tuner.results_list[t][best_hparams_tuple][0]
x = np.arange(0, cur_res['total_updates'], cur_res['updates_per_epoch'])
cur_best_avg = cur_res['best_avg']
cur_best_epoch = cur_res['best_epoch']
updates_per_epoch = cur_res['updates_per_epoch']
# print("dropout: %f, fisher_multiplier: %e, lr: %e" % (k[0], k[1], k[2]))
print("cur_best_avg: %e, num_updates: %d" % (cur_best_avg, cur_best_epoch))
print("best val_acc: %s" % (str(np.array(cur_res['val_acc'])[:, (cur_best_epoch - 1) // tuner.eval_frequency])))
# plt.plot(cur_res['loss_with_penalty'], color='g')
plt.plot(cur_res['loss'], color='m')
plt.plot(x, cur_res['val_loss'][-1], color='b')
plt.show()
# plt.ylim(ymin=0.9)
plt.plot(cur_res['val_acc'][-1], color='b', )
plt.plot(cur_res['val_acc'][0], color='g', )
# plt.plot(cur_res['val_acc'][1], color='g')

plt.show()

# %%
t = 1
learning_rates = [(((49, 1e-1), (63, 1e-1 / 5), 1e-1 / (5 * 5)), (1e-1, ))]
momentums = [0.9]
regs = [0.00001]
dropout_input_probs = [1.0]
dropout_hidden_probs = [0.9]
prod = list(itertools.product(regs, dropout_input_probs, dropout_hidden_probs, momentums, learning_rates))
hparams = []
for hparams_tuple in prod:
    cur_dict = {}
    cur_dict['reg'] = hparams_tuple[0]
    cur_dict['dropout_input_prob'] = hparams_tuple[2]
    cur_dict['dropout_hidden_prob'] = hparams_tuple[2]
    cur_dict['momentum'] = hparams_tuple[3]
    cur_dict['learning_rate'] = hparams_tuple[4]
    hparams.append(cur_dict)
    
for i in range(1, t + 1):
    tuner.hparams_list[i] = hparams

# %%
num_hparams = len(hparams)
num_epochs = 70
num_updates = math.ceil(tuner.task_list[t].train.images.shape[0] / BATCH_SIZE) * num_epochs
tuner.print_every = 100

# %%
best_avg, best_hparams_index, test_acc = tuner.tuneTasksInRange(1, t, BATCH_SIZE, num_hparams, 
                                                        num_updates=num_updates, verbose=True, 
                                                        random_crop_flip=True, 
                                                        equal_weights=True, 
                                                        eval_test_dataset=True)
# Out:
# Training with T=None,alpha=0.0,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.0,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=1
# Restoring paramters from dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0
# INFO:tensorflow:Restoring parameters from ./checkpoints_0/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-23940
# epoch: 1, iter: 0/4, validation accuracies: [0.21098901 0.        ], average train loss: 13.676358, average train accuracy: 0.298828
# epoch: 2, iter: 0/4, validation accuracies: [0.1032967 0.       ], average train loss: 7.646547, average train accuracy: 0.292969
# epoch: 3, iter: 0/4, validation accuracies: [0.06538462 0.        ], average train loss: 5.614647, average train accuracy: 0.193359
# epoch: 4, iter: 0/4, validation accuracies: [0.0521978 0.       ], average train loss: 4.645813, average train accuracy: 0.126953
# epoch: 5, iter: 0/4, validation accuracies: [0.05769231 0.        ], average train loss: 4.294170, average train accuracy: 0.130859
# epoch: 6, iter: 0/4, validation accuracies: [0.07582418 0.        ], average train loss: 4.030400, average train accuracy: 0.140625
# epoch: 7, iter: 0/4, validation accuracies: [0.09010989 0.        ], average train loss: 3.842266, average train accuracy: 0.150391
# epoch: 8, iter: 0/4, validation accuracies: [0.12307692 0.        ], average train loss: 3.629314, average train accuracy: 0.169922
# epoch: 9, iter: 0/4, validation accuracies: [0.16208791 0.        ], average train loss: 3.475870, average train accuracy: 0.203125
# epoch: 10, iter: 0/4, validation accuracies: [0.18846154 0.        ], average train loss: 3.327676, average train accuracy: 0.240234
# epoch: 11, iter: 0/4, validation accuracies: [0.20769231 0.        ], average train loss: 3.502109, average train accuracy: 0.212891
# epoch: 12, iter: 0/4, validation accuracies: [0.22197802 0.        ], average train loss: 3.187576, average train accuracy: 0.244141
# epoch: 13, iter: 0/4, validation accuracies: [0.23791209 0.        ], average train loss: 3.067739, average train accuracy: 0.294922
# epoch: 14, iter: 0/4, validation accuracies: [0.25054945 0.05      ], average train loss: 3.188687, average train accuracy: 0.267578
# epoch: 15, iter: 0/4, validation accuracies: [0.26758241 0.1       ], average train loss: 2.830354, average train accuracy: 0.343750
# epoch: 16, iter: 0/4, validation accuracies: [0.28076923 0.1       ], average train loss: 2.778029, average train accuracy: 0.330078
# epoch: 17, iter: 0/4, validation accuracies: [0.29010989 0.05      ], average train loss: 2.675075, average train accuracy: 0.365234
# epoch: 18, iter: 0/4, validation accuracies: [0.30384615 0.        ], average train loss: 2.782279, average train accuracy: 0.347656
# epoch: 19, iter: 0/4, validation accuracies: [0.30054945 0.        ], average train loss: 2.625653, average train accuracy: 0.326172
# epoch: 20, iter: 0/4, validation accuracies: [0.30164835 0.1       ], average train loss: 2.676227, average train accuracy: 0.349609
# epoch: 21, iter: 0/4, validation accuracies: [0.32032967 0.2       ], average train loss: 2.510710, average train accuracy: 0.386719
# epoch: 22, iter: 0/4, validation accuracies: [0.32912087 0.34999999], average train loss: 2.604520, average train accuracy: 0.341797
# epoch: 23, iter: 0/4, validation accuracies: [0.33626374 0.30000001], average train loss: 2.515629, average train accuracy: 0.373047
# epoch: 24, iter: 0/4, validation accuracies: [0.3434066 0.2      ], average train loss: 2.435978, average train accuracy: 0.392578
# epoch: 25, iter: 0/4, validation accuracies: [0.3521978 0.25     ], average train loss: 2.451799, average train accuracy: 0.386719
# epoch: 25, iter: 0/4, loss: 2.279979, accuracy: 0.414062
# epoch: 26, iter: 0/4, validation accuracies: [0.35219781 0.44999999], average train loss: 2.223408, average train accuracy: 0.447266
# epoch: 27, iter: 0/4, validation accuracies: [0.34340659 0.5       ], average train loss: 2.364761, average train accuracy: 0.421875
# epoch: 28, iter: 0/4, validation accuracies: [0.35494505 0.44999999], average train loss: 2.236218, average train accuracy: 0.433594
# epoch: 29, iter: 0/4, validation accuracies: [0.35714286 0.40000001], average train loss: 2.175187, average train accuracy: 0.433594
# epoch: 30, iter: 0/4, validation accuracies: [0.37527473 0.34999999], average train loss: 2.340095, average train accuracy: 0.417969
# epoch: 31, iter: 0/4, validation accuracies: [0.38021978 0.34999999], average train loss: 2.045036, average train accuracy: 0.490234
# epoch: 32, iter: 0/4, validation accuracies: [0.39065935 0.30000001], average train loss: 2.098311, average train accuracy: 0.433594
# epoch: 33, iter: 0/4, validation accuracies: [0.39175825 0.34999999], average train loss: 2.016098, average train accuracy: 0.478516
# epoch: 34, iter: 0/4, validation accuracies: [0.3945055  0.34999999], average train loss: 2.101229, average train accuracy: 0.462891
# epoch: 35, iter: 0/4, validation accuracies: [0.39285715 0.40000001], average train loss: 2.057181, average train accuracy: 0.470703
# epoch: 36, iter: 0/4, validation accuracies: [0.39615384 0.40000001], average train loss: 2.121119, average train accuracy: 0.460938
# epoch: 37, iter: 0/4, validation accuracies: [0.41538462 0.44999999], average train loss: 1.997407, average train accuracy: 0.484375
# epoch: 38, iter: 0/4, validation accuracies: [0.41263737 0.40000001], average train loss: 1.821531, average train accuracy: 0.533203
# epoch: 39, iter: 0/4, validation accuracies: [0.40714285 0.34999999], average train loss: 1.946053, average train accuracy: 0.472656
# epoch: 40, iter: 0/4, validation accuracies: [0.42142857 0.30000001], average train loss: 1.773461, average train accuracy: 0.523438
# epoch: 41, iter: 0/4, validation accuracies: [0.42197802 0.30000001], average train loss: 1.831846, average train accuracy: 0.500000
# epoch: 42, iter: 0/4, validation accuracies: [0.41483517 0.40000001], average train loss: 1.868034, average train accuracy: 0.498047
# epoch: 43, iter: 0/4, validation accuracies: [0.42967034 0.40000001], average train loss: 1.777555, average train accuracy: 0.531250
# epoch: 44, iter: 0/4, validation accuracies: [0.43186813 0.40000001], average train loss: 1.873539, average train accuracy: 0.470703
# epoch: 45, iter: 0/4, validation accuracies: [0.43351648 0.25      ], average train loss: 1.765710, average train accuracy: 0.535156
# epoch: 46, iter: 0/4, validation accuracies: [0.42417583 0.25      ], average train loss: 1.944540, average train accuracy: 0.458984
# epoch: 47, iter: 0/4, validation accuracies: [0.42527473 0.40000001], average train loss: 1.846379, average train accuracy: 0.488281
# epoch: 48, iter: 0/4, validation accuracies: [0.43021978 0.40000001], average train loss: 1.620837, average train accuracy: 0.564453
# epoch: 49, iter: 0/4, validation accuracies: [0.43956044 0.44999999], average train loss: 1.694953, average train accuracy: 0.548828
# epoch: 50, iter: 0/4, validation accuracies: [0.4532967  0.40000001], average train loss: 1.782680, average train accuracy: 0.531250
# epoch: 50, iter: 0/4, loss: 1.795460, accuracy: 0.539062
# epoch: 51, iter: 0/4, validation accuracies: [0.45824176 0.44999999], average train loss: 1.642585, average train accuracy: 0.531250
# epoch: 52, iter: 0/4, validation accuracies: [0.46373626 0.44999999], average train loss: 1.792262, average train accuracy: 0.539062
# epoch: 53, iter: 0/4, validation accuracies: [0.47307692 0.44999999], average train loss: 1.738189, average train accuracy: 0.529297
# epoch: 54, iter: 0/4, validation accuracies: [0.47912088 0.40000001], average train loss: 1.608132, average train accuracy: 0.539062
# epoch: 55, iter: 0/4, validation accuracies: [0.47967033 0.40000001], average train loss: 1.616997, average train accuracy: 0.554688
# epoch: 56, iter: 0/4, validation accuracies: [0.47802198 0.40000001], average train loss: 1.754713, average train accuracy: 0.535156
# epoch: 57, iter: 0/4, validation accuracies: [0.47637362 0.40000001], average train loss: 1.564635, average train accuracy: 0.574219
# epoch: 58, iter: 0/4, validation accuracies: [0.47692308 0.40000001], average train loss: 1.641357, average train accuracy: 0.544922
# epoch: 59, iter: 0/4, validation accuracies: [0.48186814 0.40000001], average train loss: 1.684681, average train accuracy: 0.525391
# epoch: 60, iter: 0/4, validation accuracies: [0.48351649 0.40000001], average train loss: 1.584028, average train accuracy: 0.548828
# epoch: 61, iter: 0/4, validation accuracies: [0.48186813 0.40000001], average train loss: 1.637903, average train accuracy: 0.560547
# epoch: 62, iter: 0/4, validation accuracies: [0.48516483 0.34999999], average train loss: 1.684457, average train accuracy: 0.541016
# epoch: 63, iter: 0/4, validation accuracies: [0.48461538 0.34999999], average train loss: 1.629075, average train accuracy: 0.558594
# epoch: 64, iter: 0/4, validation accuracies: [0.48571428 0.40000001], average train loss: 1.617810, average train accuracy: 0.519531
# epoch: 65, iter: 0/4, validation accuracies: [0.48571429 0.40000001], average train loss: 1.638042, average train accuracy: 0.558594
# epoch: 66, iter: 0/4, validation accuracies: [0.48406593 0.40000001], average train loss: 1.607601, average train accuracy: 0.580078
# epoch: 67, iter: 0/4, validation accuracies: [0.48736263 0.40000001], average train loss: 1.462505, average train accuracy: 0.609375
# epoch: 68, iter: 0/4, validation accuracies: [0.49065934 0.40000001], average train loss: 1.610280, average train accuracy: 0.542969
# epoch: 69, iter: 0/4, validation accuracies: [0.48956044 0.44999999], average train loss: 1.404331, average train accuracy: 0.595703
# epoch: 70, iter: 0/4, validation accuracies: [0.49340658 0.44999999], average train loss: 1.583133, average train accuracy: 0.566406
# epochs: 70.000000, final train loss: 1.548445, validation accuracies: [0.49340658 0.44999999]
# best epochs: 70.000000, best_avg: 0.492935, validation accuracies: [0.49340658 0.44999999]
# saving model dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=1 at time step 280
# calculating penultimate output...
# time taken: %f 4.929530620574951
# saving penultimate output...

# %%
print("test_acc:", test_acc)
# Out:
# test_acc: [[0.5118681318812318, 0.4099999964237213]]

# %%
plt.rcParams['figure.figsize'] = [10, 10]
best_hparams_tuple = tuner.hparamsDictToTuple(hparams[0], tuner.tuner_hparams)
cur_res = tuner.results_list[t][best_hparams_tuple][0]
x = np.arange(0, cur_res['total_updates'], cur_res['updates_per_epoch'])
cur_best_avg = cur_res['best_avg']
cur_best_epoch = cur_res['best_epoch']
updates_per_epoch = cur_res['updates_per_epoch']
# print("dropout: %f, fisher_multiplier: %e, lr: %e" % (k[0], k[1], k[2]))
print("cur_best_avg: %e, num_updates: %d" % (cur_best_avg, cur_best_epoch))
print("best val_acc: %s" % (str(np.array(cur_res['val_acc'])[:, (cur_best_epoch - 1) // tuner.eval_frequency])))
# plt.plot(cur_res['loss_with_penalty'], color='g')
# plt.plot(cur_res['loss'], color='m')
# plt.plot(x, cur_res['val_loss'][-1], color='b')
# plt.show()
# plt.ylim(ymin=0.9)
plt.plot(cur_res['val_acc'][-1], color='b', )
plt.plot(cur_res['val_acc'][0], color='g', )
# plt.plot(cur_res['val_acc'][1], color='g')

plt.show()

# %%
def getAllCosineSimilarity(wts, init_classes, only_dot=False):
    num_init_class = len(init_classes)
    cosine_wts = [[0.0 for _ in range(num_init_class)] for _ in range(num_init_class)]
    for i in range(num_init_class):
        for j in range(num_init_class):
            w_i = wts[0][:, init_classes[i]]
            w_j = wts[0][:, init_classes[j]]
            if (only_dot):
                cosine_wts[i][j] = np.sum(w_i * w_j)
            else:
                cosine_wts[i][j] = np.sum(w_i * w_j) / np.sqrt(np.sum(w_i ** 2)) / np.sqrt(np.sum(w_j ** 2))
    return cosine_wts

# %%
num_tasks_test = 10
wts = [None for _ in range(num_tasks_test)]
init_classes = tuner.split[0]
cosine_sim_wts = [None for _ in range(num_tasks_test)]
dot_sim_wts = [None for _ in range(num_tasks_test)]
for i in range(num_tasks_test):
    tuner.test(i, BATCH_SIZE, restore_model=True, hparams=tuner.hparams_list[i][0])
    wts[i] = sess.run([v for v in tf.all_variables() if 'dense' in v.name and 'kernel:0' in v.name])
    cosine_sim_wts[i] = np.array(getAllCosineSimilarity(wts[i], init_classes, only_dot=False))
    dot_sim_wts[i] = np.array(getAllCosineSimilarity(wts[i], init_classes, only_dot=True))

# %%
for i in range(num_tasks_test):
#     plt.imshow(cosine_sim_wts[i])
    print("task", i)
    print("sum cosine: ", np.sum(cosine_sim_wts[i]) - num_init_class)
    print("sum dot: ", np.sum(dot_sim_wts[i]) - np.sum(wts[i][0][: , init_classes] ** 2))
    print("sum norms: ", np.sum(np.sqrt(np.sum(wts[i][0][:, init_classes] ** 2, axis=0))))
#     plt.show()

# %%
tuner.saveResultsList()
tuner.saveBestHparams()

# %%
TEST_BATCH_SIZE = 128
test_accuracies = []
for i in range(t + 1):
    accuracy = tuner.test(i, TEST_BATCH_SIZE, restore_model=False)
    test_accuracies.append(accuracy)

# %%
for i in range(t + 1):
    print(test_accuracies[i])

# %%
if use_tpu:
    sess.run(tpu.shutdown_system())

sess.close()

# %%
import shelve
filename='code_state.bak'
my_shelf = shelve.open(filename,'n') # 'n' for new

for key in dir():
    try:
        my_shelf[key] = globals()[key]
    except TypeError:
        #
        # __builtins__, my_shelf, and imported modules can not be shelved.
        #
        print('ERROR shelving: {0}'.format(key))
my_shelf.close()
