# %% [markdown]
# ### Import and init GPU

# %%
from IPython.display import Audio

# %%
import sys
sys.path.append('../../../')

# %%
import numpy as np
import math

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn

import pickle
import argparse
import time
import itertools
from copy import deepcopy
import tensorflow as tf

from tuner import HyperparameterTuner
from tuner import MyTask

use_tpu = False
use_gpu = True

if use_tpu:
    from tensorflow.contrib import tpu
    from tensorflow.contrib.cluster_resolver import TPUClusterResolver

if use_gpu:
    import os
    
# %load_ext autoreload
# %autoreload 2

# %%
if use_gpu:
    os.environ['CUDA_VISIBLE_DEVICES'] = '0'
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True

# %%
if use_tpu:
    tpu_cluster = TPUClusterResolver(tpu=[tpu_name]).get_master()
    sess = tf.Session(tpu_cluster)
    sess.run(tpu.initialize_system())
elif use_gpu:
    sess = tf.Session(config=config)
else:
    sess = tf.Session()

# %%
from resnet import Network

# %%
network = Network()

# %%
task_home = ''
if use_tpu:
    pass
#     task_home = 'gs://continual_learning/permMNIST_EWC/'
else:
    task_home = '../../../../'

cur_dir = './'
checkpoint_path = cur_dir + 'checkpoints_99_1_0_distill/'
summaries_path = cur_dir + 'summaries_99_1_0_distill/'
data_path = task_home + 'cifar-100-python/'
split_path = './split.txt' 
if use_tpu:
    tpu_name = 'gectpu'
    
BATCH_SIZE = 128

# %% [markdown]
# ### Dataset loading functions

# %%
label_smooth_param = 0

def splitDataset(dataset, dataset_split, seed):
    np.random.seed(seed)
    task_list = []
    train_labels = np.argmax(dataset.train.labels, axis=1)
    validation_labels = np.argmax(dataset.validation.labels, axis=1)
    test_labels = np.argmax(dataset.test.labels, axis=1)
    for i in range(len(dataset_split)):
        cur_train_indices = [False] * dataset.train.images.shape[0]
        cur_validation_indices = [False] * dataset.validation.images.shape[0]
        cur_test_indices = [False] * dataset.test.images.shape[0]
        for j in range(len(dataset_split[i])):
            cur_train_indices = np.logical_or(cur_train_indices, (train_labels == dataset_split[i][j]))
            cur_validation_indices = np.logical_or(cur_validation_indices, (validation_labels == dataset_split[i][j]))
            cur_test_indices = np.logical_or(cur_test_indices, (test_labels == dataset_split[i][j]))

        task = deepcopy(dataset)
        task.train.images = task.train.images[cur_train_indices]
        task.train.labels = task.train.labels[cur_train_indices]
        task.validation.images = task.validation.images[cur_validation_indices]
        task.validation.labels = task.validation.labels[cur_validation_indices]
        task.test.images = task.test.images[cur_test_indices]
        task.test.labels = task.test.labels[cur_test_indices]
        task = MyTask(task)
        task_list.append(task)

    return task_list
    
def smoothLabels(dataset):
    train_labels = dataset.train.labels
    train_labels_argmax = np.argmax(train_labels, axis=1)
    train_labels = train_labels + label_smooth_param / (train_labels.shape[1] - 1)
    train_labels[range(train_labels.shape[0]), train_labels_argmax] = 1 - label_smooth_param
    dataset.train._labels = train_labels

class TempDataset(object):
    def __init__(self):
        self.images = None
        self.labels = None
    
class TempTask(object):
    def __init__(self):
        self.train = TempDataset()
        self.validation = TempDataset()
        self.test = TempDataset()
    
    
def readDatasets():
    num_class = 100
    class_per_task = 2
    k = 0
    labels_list = list(range(num_class))
    seed = 0
    np.random.seed(seed)
    np.random.shuffle(labels_list)
    split = []
    task_weights = []
    
    split = [range(99), [99]]
    task_weights = [0.99, 0.01]
    num_tasks = len(split)
    
    with open(data_path + 'train', 'rb') as f:
        f_train_data = pickle.load(f, encoding='bytes')
        
    with open(data_path + 'test', 'rb') as f:
        f_test_data = pickle.load(f, encoding='bytes')
        
    cifar_100 = TempTask()
    temp_train_labels = np.array(f_train_data[b'fine_labels'], dtype=np.int32)
    temp_test_labels = np.array(f_test_data[b'fine_labels'], dtype=np.int32)
    f_train_data[b'fine_labels'] = np.zeros((temp_train_labels.shape[0], num_class))
    (f_train_data[b'fine_labels'])[range(temp_train_labels.shape[0]), temp_train_labels] = 1
    f_test_data[b'fine_labels'] = np.zeros((temp_test_labels.shape[0], num_class))
    (f_test_data[b'fine_labels'])[range(temp_test_labels.shape[0]), temp_test_labels] = 1
    f_train_data[b'data'] = np.reshape(f_train_data[b'data'], (-1, 3, 32, 32))
    f_test_data[b'data'] = np.reshape(f_test_data[b'data'], (-1, 3, 32, 32))
    f_train_data[b'data'] = np.transpose(f_train_data[b'data'], (0, 2, 3, 1))
    f_test_data[b'data'] = np.transpose(f_test_data[b'data'], (0, 2, 3, 1))
    
    tr_data = f_train_data[b'data']
    te_data = f_test_data[b'data']
    # normalizing data
    avg = np.mean(tr_data, axis=(0, 1, 2))
    std = np.std(tr_data, axis=(0, 1, 2))
    
    f_train_data[b'data'] = (tr_data - avg) / std
    f_test_data[b'data'] = (te_data - avg) / std
    
    seed = 0
    np.random.seed(0)
    shuffle_train_perm = np.random.permutation(f_train_data[b'data'].shape[0])
    f_train_data[b'data'] = f_train_data[b'data'][shuffle_train_perm]
    f_train_data[b'fine_labels'] = f_train_data[b'fine_labels'][shuffle_train_perm]
    
    num_val_per_class = 20
    
    for i in range(num_class):
        pos = (np.argmax(f_train_data[b'fine_labels'], axis=1) == i)
        
        if (i == 0):
            cifar_100.validation.images = (f_train_data[b'data'][pos])[0 : num_val_per_class]
            cifar_100.validation.labels = (f_train_data[b'fine_labels'][pos])[0 : num_val_per_class]

            cifar_100.train.images = (f_train_data[b'data'][pos])[num_val_per_class : ]
            cifar_100.train.labels = (f_train_data[b'fine_labels'][pos])[num_val_per_class : ]
        else:
            cifar_100.validation.images = np.concatenate((cifar_100.validation.images, (f_train_data[b'data'][pos])[0 : num_val_per_class]))
            cifar_100.validation.labels = np.concatenate((cifar_100.validation.labels, (f_train_data[b'fine_labels'][pos])[0 : num_val_per_class]))

            cifar_100.train.images = np.concatenate((cifar_100.train.images, (f_train_data[b'data'][pos])[num_val_per_class : ]))
            cifar_100.train.labels = np.concatenate((cifar_100.train.labels, (f_train_data[b'fine_labels'][pos])[num_val_per_class : ]))
        
    cifar_100.test.images = f_test_data[b'data']
    cifar_100.test.labels = f_test_data[b'fine_labels']
    
    shuffle_train_perm = np.random.permutation(cifar_100.train.images.shape[0])
    cifar_100.train.images = cifar_100.train.images[shuffle_train_perm]
    cifar_100.train.labels = cifar_100.train.labels[shuffle_train_perm]
    
    if (label_smooth_param != 0):
        smoothLabels(cifar_100)
        
    task_list = splitDataset(cifar_100, split, seed)
    return split, num_tasks, task_weights, task_list

# %% [markdown]
# ### Display sample images and label names

# %%
with open(data_path + 'train', 'rb') as f:
    f_train_data = pickle.load(f, encoding='bytes')
    
with open(data_path + 'meta', 'rb') as f:
    f_meta_data = pickle.load(f, encoding='bytes')

# %%
print(f_meta_data[b'fine_label_names'][78])
print(f_meta_data[b'fine_label_names'][61])
print(f_meta_data[b'fine_label_names'][99])

# %% [markdown]
# ### Create tuner object and train!!

# %%
input_shape = (32, 32, 3)
output_shape = (100, )

# %%
tuner = HyperparameterTuner(sess=sess, network=network, 
                            input_shape=input_shape, output_shape=output_shape,
                            checkpoint_path=checkpoint_path, summaries_path=summaries_path, 
                            readDatasets=readDatasets, load_best_hparams=False, 
                            reweigh_points_loss=False)
# Out:
# WARNING:tensorflow:From ../../../classifiers.py:103: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
tuner.setPerExampleAppend(int(1))
tuner.updateTunerHparams({'mask_softmax' : True})
tuner.updateTunerHparams({'bf_num_images' : 2000})
tuner.setPerExampleAppend(1.0)

# %% [markdown]
# ### Training each task separately

# %%
t = 0
learning_rates = [1e-1]
momentums = [0.9]
regs = [0.0001]
dropout_input_probs = [1.0]
dropout_hidden_probs = [0.9]
prod = list(itertools.product(regs, dropout_input_probs, dropout_hidden_probs, momentums, learning_rates))
hparams = []
for hparams_tuple in prod:
    cur_dict = {}
    cur_dict['reg'] = hparams_tuple[0]
    cur_dict['dropout_input_prob'] = hparams_tuple[2]
    cur_dict['dropout_hidden_prob'] = hparams_tuple[2]
    cur_dict['momentum'] = hparams_tuple[3]
    cur_dict['learning_rate'] = hparams_tuple[4]
    hparams.append(cur_dict)

tuner.hparams_list[t] = hparams

# %%
num_epochs = 160
num_updates = math.ceil(tuner.task_list[t].train.images.shape[0] / BATCH_SIZE) * num_epochs
tuner.print_every = 10

# %%
start_time = time.time()
best_avg, best_hparams = tuner.tuneOnTask(t, BATCH_SIZE, 
                                          save_weights=False, 
                                          num_updates=num_updates, verbose=True, 
                                          random_crop_flip=True)
print("time taken : %d" % (time.time() - start_time))
sound_file = '/mnt/a99/d0/shriramsb/code/Alan Walker - Alone.mp3'
Audio(sound_file, autoplay=True)

# %%
import math
plt.rcParams['figure.figsize'] = [10, 5]
lr_scatter = ([math.log10(h['learning_rate']) for h in hparams])
dropout_scatter = [h['dropout_hidden_prob'] for h in hparams]
colors = []
for i in range(len(hparams)):
    cur_hparam_tuple = tuner.hparamsDictToTuple(hparams[i], tuner.tuner_hparams)
    colors.append(tuner.results_list[t][cur_hparam_tuple]['best_avg'])
    
marker_size = 100
fig, ax = plt.subplots()
plt.scatter(lr_scatter, dropout_scatter, marker_size, c=colors, edgecolors='black')
plt.colorbar()
for i in range(len(lr_scatter)):
    ax.annotate(str('%0.4f' % (colors[i], )), (lr_scatter[i], dropout_scatter[i]))
plt.show()

# %%
plt.rcParams['figure.figsize'] = [10, 10]
best_hparams_tuple = tuner.hparamsDictToTuple(hparams[0], tuner.tuner_hparams)
cur_res = tuner.results_list[t][best_hparams_tuple]
x = np.arange(0, cur_res['total_updates'], cur_res['updates_per_epoch'])
cur_best_avg = cur_res['best_avg']
cur_best_avg_updates = cur_res['best_avg_updates']
updates_per_epoch = cur_res['updates_per_epoch']
# print("dropout: %f, fisher_multiplier: %e, lr: %e" % (k[0], k[1], k[2]))
print("cur_best_avg: %e, num_updates: %d" % (cur_best_avg, cur_best_avg_updates))
print("best val_acc: %s" % (str(np.array(cur_res['val_acc'])[:, (cur_best_avg_updates // updates_per_epoch - 1) // tuner.eval_frequency])))
# plt.plot(cur_res['loss_with_penalty'], color='g')
plt.plot(cur_res['loss'], color='m')
plt.plot(x, cur_res['val_loss'][-1], color='b')
plt.show()
# plt.ylim(ymin=0.9)
plt.plot(cur_res['val_acc'][0], color='b', )
# plt.plot(cur_res['val_acc'][1], color='g')

plt.show()

# %%
# print(best_avg, best_hparams)
VALIDATION_BATCH_SIZE = 128
print(tuner.validationAccuracy(t, VALIDATION_BATCH_SIZE, restore_model=False))

# %%
t = 1
learning_rates = [1e-1]
momentums = [0.9]
regs = [0.0001]
dropout_input_probs = [1.0]
dropout_hidden_probs = [0.9]
prod = list(itertools.product(regs, dropout_input_probs, dropout_hidden_probs, momentums, learning_rates))
hparams = []
for hparams_tuple in prod:
    cur_dict = {}
    cur_dict['reg'] = hparams_tuple[0]
    cur_dict['dropout_input_prob'] = hparams_tuple[2]
    cur_dict['dropout_hidden_prob'] = hparams_tuple[2]
    cur_dict['momentum'] = hparams_tuple[3]
    cur_dict['learning_rate'] = hparams_tuple[4]
    hparams.append(cur_dict)

tuner.hparams_list[t] = hparams

# %%
num_epochs = 160
num_updates = math.ceil(tuner.task_list[t].train.images.shape[0] / BATCH_SIZE) * num_epochs
tuner.print_every = 10

# %%
start_time = time.time()
best_avg, best_hparams = tuner.tuneOnTask(t, BATCH_SIZE, 
                                          save_weights=False, 
                                          num_updates=num_updates, verbose=True, 
                                          random_crop_flip=True)
print("time taken : %d" % (time.time() - start_time))
sound_file = '/mnt/a99/d0/shriramsb/code/Alan Walker - Alone.mp3'
Audio(sound_file, autoplay=True)

# %%
import math
plt.rcParams['figure.figsize'] = [10, 5]
lr_scatter = ([math.log10(h['learning_rate']) for h in hparams])
dropout_scatter = [h['dropout_hidden_prob'] for h in hparams]
colors = []
for i in range(len(hparams)):
    cur_hparam_tuple = tuner.hparamsDictToTuple(hparams[i], tuner.tuner_hparams)
    colors.append(tuner.results_list[t][cur_hparam_tuple]['best_avg'])
    
marker_size = 100
fig, ax = plt.subplots()
plt.scatter(lr_scatter, dropout_scatter, marker_size, c=colors, edgecolors='black')
plt.colorbar()
for i in range(len(lr_scatter)):
    ax.annotate(str('%0.4f' % (colors[i], )), (lr_scatter[i], dropout_scatter[i]))
plt.show()

# %%
plt.rcParams['figure.figsize'] = [10, 10]
best_hparams_tuple = tuner.hparamsDictToTuple(hparams[0], tuner.tuner_hparams)
cur_res = tuner.results_list[t][best_hparams_tuple]
x = np.arange(0, cur_res['total_updates'], cur_res['updates_per_epoch'])
cur_best_avg = cur_res['best_avg']
cur_best_avg_updates = cur_res['best_avg_updates']
updates_per_epoch = cur_res['updates_per_epoch']
# print("dropout: %f, fisher_multiplier: %e, lr: %e" % (k[0], k[1], k[2]))
print("cur_best_avg: %e, num_updates: %d" % (cur_best_avg, cur_best_avg_updates))
print("best val_acc: %s" % (str(np.array(cur_res['val_acc'])[:, (cur_best_avg_updates // updates_per_epoch - 1) // tuner.eval_frequency])))
# plt.plot(cur_res['loss_with_penalty'], color='g')
plt.plot(cur_res['loss'], color='m')
plt.plot(x, cur_res['val_loss'][-1], color='b')
plt.show()
# plt.ylim(ymin=0.9)
plt.plot(cur_res['val_acc'][0], color='b', )
plt.plot(cur_res['val_acc'][1], color='g')

plt.show()

# %% [markdown]
# ### Train tasks together

# %%
t = 0
learning_rates = [(((49, 1e-1), (63, 1e-1 / 5), 1e-1 / (5 * 5)), (1e-1, ))]
momentums = [0.9]
regs = [0.00001]
dropout_input_probs = [1.0]
dropout_hidden_probs = [0.9]
prod = list(itertools.product(regs, dropout_input_probs, dropout_hidden_probs, momentums, learning_rates))
hparams = []
for hparams_tuple in prod:
    cur_dict = {}
    cur_dict['reg'] = hparams_tuple[0]
    cur_dict['dropout_input_prob'] = hparams_tuple[2]
    cur_dict['dropout_hidden_prob'] = hparams_tuple[2]
    cur_dict['momentum'] = hparams_tuple[3]
    cur_dict['learning_rate'] = hparams_tuple[4]
    hparams.append(cur_dict)
    
for i in range(0, t + 1):
    tuner.hparams_list[i] = hparams

# %%
t = 1
learning_rates = [(((20, 1e-1), (30, 1e-1 / 5), 1e-1 / 25), ((20, 1e-2), 1e-2 / 5))]
momentums = [0.9]
regs = [0.00001]
dropout_input_probs = [1.0]
dropout_hidden_probs = [0.9]
# epsilons = [1.0]
T = [5]
alphas = [0.5]
epsilons = [0.0, 0.1, 0.2, 0.4, 0.5, 0.7, 1.0]
prod = list(itertools.product(T, alphas, regs, dropout_input_probs, dropout_hidden_probs, momentums, learning_rates, 
                                epsilons))
hparams = []
for hparams_tuple in prod:
    cur_dict = {}
    cur_dict['T'] = hparams_tuple[0]
    cur_dict['alpha'] = hparams_tuple[1]
    cur_dict['reg'] = hparams_tuple[2]
    cur_dict['dropout_input_prob'] = hparams_tuple[4]
    cur_dict['dropout_hidden_prob'] = hparams_tuple[4]
    cur_dict['momentum'] = hparams_tuple[5]
    cur_dict['learning_rate'] = hparams_tuple[6]
    cur_dict['epsilon'] = hparams_tuple[7]
    hparams.append(cur_dict)
    
for i in range(t, t + 1):
    tuner.hparams_list[i] = hparams

for i in range(0, t):
    for _ in range(len(hparams)):
        tuner.hparams_list[i].append(tuner.hparams_list[i][0])

# %%
tuner.setPerExampleAppend(5.0)
num_hparams = len(hparams)
num_epochs = 40
num_updates = math.ceil(tuner.task_list[t].train.images.shape[0] / BATCH_SIZE) * num_epochs
num_epochs_bf = 30
num_updates_bf = math.ceil(tuner.task_list[t].train.images.shape[0] / BATCH_SIZE) * num_epochs_bf

# %%
best_avg, best_hparams_index = tuner.tuneTasksInRange(1, t, BATCH_SIZE, num_hparams, 
                                                        num_updates=num_updates, verbose=True, 
                                                        random_crop_flip=True, 
                                                        is_sampling_reweighing=True, 
                                                        do_bf_finetuning=True, num_updates_bf=num_updates_bf, 
                                                        bf_only_penultimate_train=False, 
                                                        sigma=1.0)
# Out:
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.0,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# Restoring paramters from dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# epoch: 1, iter: 0/4, validation accuracies: [0.63585857 0.        ], average train loss: 42.409630, average train accuracy: 0.744141
# epoch: 2, iter: 0/4, validation accuracies: [0.55303032 0.34999999], average train loss: 40.974625, average train accuracy: 0.767578
# epoch: 3, iter: 0/4, validation accuracies: [0.42929293 0.80000001], average train loss: 40.802273, average train accuracy: 0.705078
# epoch: 4, iter: 0/4, validation accuracies: [0.58232323 0.30000001], average train loss: 41.338112, average train accuracy: 0.701172
# epoch: 5, iter: 0/4, validation accuracies: [0.59696968 0.34999999], average train loss: 41.080406, average train accuracy: 0.732422
# epoch: 6, iter: 0/4, validation accuracies: [0.54242425 0.75      ], average train loss: 41.773098, average train accuracy: 0.757812
# epoch: 7, iter: 0/4, validation accuracies: [0.48232324 0.94999999], average train loss: 41.746902, average train accuracy: 0.777344
# epoch: 8, iter: 0/4, validation accuracies: [0.58232322 0.80000001], average train loss: 40.862350, average train accuracy: 0.750000
# epoch: 9, iter: 0/4, validation accuracies: [0.57979799 0.75      ], average train loss: 40.924149, average train accuracy: 0.792969
# epoch: 10, iter: 0/4, validation accuracies: [0.57070708 1.        ], average train loss: 40.865185, average train accuracy: 0.791016
# epoch: 11, iter: 0/4, validation accuracies: [0.56010102 0.94999999], average train loss: 41.575035, average train accuracy: 0.816406
# epoch: 12, iter: 0/4, validation accuracies: [0.55303031 0.89999998], average train loss: 42.166328, average train accuracy: 0.779297
# epoch: 13, iter: 0/4, validation accuracies: [0.5641414  0.85000002], average train loss: 40.622566, average train accuracy: 0.789062
# epoch: 14, iter: 0/4, validation accuracies: [0.56969697 0.94999999], average train loss: 41.129673, average train accuracy: 0.794922
# epoch: 15, iter: 0/4, validation accuracies: [0.57929292 0.89999998], average train loss: 40.526035, average train accuracy: 0.804688
# epoch: 16, iter: 0/4, validation accuracies: [0.56717173 0.94999999], average train loss: 41.154797, average train accuracy: 0.814453
# epoch: 17, iter: 0/4, validation accuracies: [0.58737373 0.85000002], average train loss: 41.232342, average train accuracy: 0.789062
# epoch: 18, iter: 0/4, validation accuracies: [0.58333332 0.80000001], average train loss: 40.421246, average train accuracy: 0.791016
# epoch: 19, iter: 0/4, validation accuracies: [0.60101009 0.85000002], average train loss: 41.848511, average train accuracy: 0.814453
# epoch: 20, iter: 0/4, validation accuracies: [0.58636363 0.94999999], average train loss: 41.541779, average train accuracy: 0.761719
# epoch: 21, iter: 0/4, validation accuracies: [0.60151514 1.        ], average train loss: 40.289661, average train accuracy: 0.816406
# epoch: 22, iter: 0/4, validation accuracies: [0.61111112 1.        ], average train loss: 41.337517, average train accuracy: 0.808594
# epoch: 23, iter: 0/4, validation accuracies: [0.60959596 1.        ], average train loss: 40.867523, average train accuracy: 0.796875
# epoch: 24, iter: 0/4, validation accuracies: [0.62222221 1.        ], average train loss: 41.349480, average train accuracy: 0.828125
# epoch: 25, iter: 0/4, validation accuracies: [0.61565658 1.        ], average train loss: 40.916473, average train accuracy: 0.863281
# epoch: 26, iter: 0/4, validation accuracies: [0.62424242 1.        ], average train loss: 40.341545, average train accuracy: 0.820312
# epoch: 27, iter: 0/4, validation accuracies: [0.61818182 1.        ], average train loss: 41.002365, average train accuracy: 0.833984
# epoch: 28, iter: 0/4, validation accuracies: [0.63030304 1.        ], average train loss: 40.596001, average train accuracy: 0.841797
# epoch: 29, iter: 0/4, validation accuracies: [0.63282829 1.        ], average train loss: 40.640755, average train accuracy: 0.845703
# epoch: 30, iter: 0/4, validation accuracies: [0.63434343 1.        ], average train loss: 40.613518, average train accuracy: 0.824219
# epoch: 31, iter: 0/4, validation accuracies: [0.63939395 1.        ], average train loss: 40.222000, average train accuracy: 0.859375
# epoch: 32, iter: 0/4, validation accuracies: [0.63939394 1.        ], average train loss: 40.417900, average train accuracy: 0.853516
# epoch: 33, iter: 0/4, validation accuracies: [0.63939395 1.        ], average train loss: 40.398373, average train accuracy: 0.843750
# epoch: 34, iter: 0/4, validation accuracies: [0.63787878 1.        ], average train loss: 40.878109, average train accuracy: 0.820312
# epoch: 35, iter: 0/4, validation accuracies: [0.63636364 1.        ], average train loss: 40.682056, average train accuracy: 0.845703
# epoch: 36, iter: 0/4, validation accuracies: [0.63838384 1.        ], average train loss: 40.304253, average train accuracy: 0.830078
# epoch: 37, iter: 0/4, validation accuracies: [0.639899 1.      ], average train loss: 40.035507, average train accuracy: 0.845703
# epoch: 38, iter: 0/4, validation accuracies: [0.63686869 1.        ], average train loss: 40.984043, average train accuracy: 0.863281
# epoch: 39, iter: 0/4, validation accuracies: [0.63787879 1.        ], average train loss: 40.679890, average train accuracy: 0.865234
# epoch: 40, iter: 0/4, validation accuracies: [0.63989899 1.        ], average train loss: 41.345581, average train accuracy: 0.837891
# epochs: 40.000000, final train loss: 41.537712, validation accuracies: [0.63989899 1.        ]
# best epochs: 37.000000, best_avg: 0.643500, validation accuracies: [0.639899 1.      ]
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.0,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# epoch: 1, iter: 0/4, validation accuracies: [0.63838384 0.89999998], average train loss: 0.496689, average train accuracy: 0.826172
# epoch: 2, iter: 0/4, validation accuracies: [0.64242424 0.85000002], average train loss: 0.410447, average train accuracy: 0.865234
# epoch: 3, iter: 0/4, validation accuracies: [0.64595959 0.80000001], average train loss: 0.403219, average train accuracy: 0.875000
# epoch: 4, iter: 0/4, validation accuracies: [0.64646464 0.80000001], average train loss: 0.402935, average train accuracy: 0.873047
# epoch: 5, iter: 0/4, validation accuracies: [0.65202021 0.75      ], average train loss: 0.405122, average train accuracy: 0.863281
# epoch: 6, iter: 0/4, validation accuracies: [0.65303029 0.64999998], average train loss: 0.425715, average train accuracy: 0.871094
# epoch: 7, iter: 0/4, validation accuracies: [0.65606061 0.64999998], average train loss: 0.381675, average train accuracy: 0.892578
# epoch: 8, iter: 0/4, validation accuracies: [0.6550505  0.64999998], average train loss: 0.386200, average train accuracy: 0.855469
# epoch: 9, iter: 0/4, validation accuracies: [0.65858586 0.64999998], average train loss: 0.310425, average train accuracy: 0.910156
# epoch: 10, iter: 0/4, validation accuracies: [0.65909092 0.64999998], average train loss: 0.406125, average train accuracy: 0.890625
# epoch: 11, iter: 0/4, validation accuracies: [0.65757576 0.64999998], average train loss: 0.342574, average train accuracy: 0.886719
# epoch: 12, iter: 0/4, validation accuracies: [0.66060606 0.64999998], average train loss: 0.387215, average train accuracy: 0.869141
# epoch: 13, iter: 0/4, validation accuracies: [0.65858586 0.64999998], average train loss: 0.307177, average train accuracy: 0.916016
# epoch: 14, iter: 0/4, validation accuracies: [0.65707069 0.64999998], average train loss: 0.280765, average train accuracy: 0.904297
# epoch: 15, iter: 0/4, validation accuracies: [0.65505052 0.64999998], average train loss: 0.362341, average train accuracy: 0.884766
# epoch: 16, iter: 0/4, validation accuracies: [0.65606059 0.64999998], average train loss: 0.278167, average train accuracy: 0.898438
# epoch: 17, iter: 0/4, validation accuracies: [0.65101009 0.64999998], average train loss: 0.308777, average train accuracy: 0.902344
# epoch: 18, iter: 0/4, validation accuracies: [0.64949494 0.64999998], average train loss: 0.305998, average train accuracy: 0.900391
# epoch: 19, iter: 0/4, validation accuracies: [0.65202021 0.64999998], average train loss: 0.325358, average train accuracy: 0.904297
# epoch: 20, iter: 0/4, validation accuracies: [0.65202019 0.64999998], average train loss: 0.251395, average train accuracy: 0.925781
# epoch: 21, iter: 0/4, validation accuracies: [0.65252526 0.64999998], average train loss: 0.244808, average train accuracy: 0.923828
# epoch: 22, iter: 0/4, validation accuracies: [0.64747475 0.64999998], average train loss: 0.289061, average train accuracy: 0.904297
# epoch: 23, iter: 0/4, validation accuracies: [0.65050505 0.64999998], average train loss: 0.329828, average train accuracy: 0.904297
# epoch: 24, iter: 0/4, validation accuracies: [0.65050504 0.64999998], average train loss: 0.239265, average train accuracy: 0.921875
# epoch: 25, iter: 0/4, validation accuracies: [0.65202019 0.64999998], average train loss: 0.356182, average train accuracy: 0.890625
# epoch: 26, iter: 0/4, validation accuracies: [0.65101011 0.64999998], average train loss: 0.265559, average train accuracy: 0.919922
# epoch: 27, iter: 0/4, validation accuracies: [0.65101011 0.64999998], average train loss: 0.260190, average train accuracy: 0.931641
# epoch: 28, iter: 0/4, validation accuracies: [0.65202021 0.64999998], average train loss: 0.348403, average train accuracy: 0.888672
# epoch: 29, iter: 0/4, validation accuracies: [0.65353535 0.64999998], average train loss: 0.311964, average train accuracy: 0.900391
# epoch: 30, iter: 0/4, validation accuracies: [0.65151514 0.64999998], average train loss: 0.319717, average train accuracy: 0.902344
# epochs: 30.000000, final train loss: 0.281572, validation accuracies: [0.65151514 0.64999998]
# best epochs: 12.000000, best_avg: 0.660500, validation accuracies: [0.66060606 0.64999998]
# saving model T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1 at time step 280
# calculating penultimate output...
# time taken: %f 6.8618292808532715
# saving penultimate output...
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.1,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# Restoring paramters from dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# epoch: 1, iter: 0/4, validation accuracies: [0.62727273 0.        ], average train loss: 41.714653, average train accuracy: 0.761719
# epoch: 2, iter: 0/4, validation accuracies: [0.60808082 0.2       ], average train loss: 41.589321, average train accuracy: 0.750000
# epoch: 3, iter: 0/4, validation accuracies: [0.40909091 0.64999998], average train loss: 40.602692, average train accuracy: 0.726562
# epoch: 4, iter: 0/4, validation accuracies: [0.56363635 0.25      ], average train loss: 40.952972, average train accuracy: 0.677734
# epoch: 5, iter: 0/4, validation accuracies: [0.59444444 0.25      ], average train loss: 40.729378, average train accuracy: 0.748047
# epoch: 6, iter: 0/4, validation accuracies: [0.57171718 0.75      ], average train loss: 40.594681, average train accuracy: 0.734375
# epoch: 7, iter: 0/4, validation accuracies: [0.56161616 0.89999998], average train loss: 41.854454, average train accuracy: 0.757812
# epoch: 8, iter: 0/4, validation accuracies: [0.60252525 0.80000001], average train loss: 41.807701, average train accuracy: 0.804688
# epoch: 9, iter: 0/4, validation accuracies: [0.5939394  0.80000001], average train loss: 41.717312, average train accuracy: 0.785156
# epoch: 10, iter: 0/4, validation accuracies: [0.58282829 0.94999999], average train loss: 41.312920, average train accuracy: 0.796875
# epoch: 11, iter: 0/4, validation accuracies: [0.57929292 1.        ], average train loss: 41.508797, average train accuracy: 0.757812
# epoch: 12, iter: 0/4, validation accuracies: [0.55353536 0.94999999], average train loss: 41.215782, average train accuracy: 0.808594
# epoch: 13, iter: 0/4, validation accuracies: [0.57474746 0.85000002], average train loss: 40.807243, average train accuracy: 0.802734
# epoch: 14, iter: 0/4, validation accuracies: [0.58636363 0.80000001], average train loss: 41.295208, average train accuracy: 0.818359
# epoch: 15, iter: 0/4, validation accuracies: [0.54898991 1.        ], average train loss: 41.887440, average train accuracy: 0.779297
# epoch: 16, iter: 0/4, validation accuracies: [0.58838384 1.        ], average train loss: 41.572548, average train accuracy: 0.789062
# epoch: 17, iter: 0/4, validation accuracies: [0.57979798 0.89999998], average train loss: 42.194683, average train accuracy: 0.785156
# epoch: 18, iter: 0/4, validation accuracies: [0.58181819 0.85000002], average train loss: 41.097206, average train accuracy: 0.810547
# epoch: 19, iter: 0/4, validation accuracies: [0.59696969 0.85000002], average train loss: 40.894325, average train accuracy: 0.812500
# epoch: 20, iter: 0/4, validation accuracies: [0.58787879 0.94999999], average train loss: 41.327904, average train accuracy: 0.800781
# epoch: 21, iter: 0/4, validation accuracies: [0.60606059 0.94999999], average train loss: 41.384529, average train accuracy: 0.792969
# epoch: 22, iter: 0/4, validation accuracies: [0.61969696 0.94999999], average train loss: 40.445469, average train accuracy: 0.841797
# epoch: 23, iter: 0/4, validation accuracies: [0.62676769 1.        ], average train loss: 40.770195, average train accuracy: 0.814453
# epoch: 24, iter: 0/4, validation accuracies: [0.62929292 0.94999999], average train loss: 41.402470, average train accuracy: 0.812500
# epoch: 25, iter: 0/4, validation accuracies: [0.62676766 1.        ], average train loss: 40.547318, average train accuracy: 0.832031
# epoch: 26, iter: 0/4, validation accuracies: [0.63282829 0.94999999], average train loss: 40.752426, average train accuracy: 0.826172
# epoch: 27, iter: 0/4, validation accuracies: [0.6328283  0.94999999], average train loss: 41.120167, average train accuracy: 0.812500
# epoch: 28, iter: 0/4, validation accuracies: [0.63030303 1.        ], average train loss: 40.259258, average train accuracy: 0.837891
# epoch: 29, iter: 0/4, validation accuracies: [0.62676766 1.        ], average train loss: 41.523865, average train accuracy: 0.853516
# epoch: 30, iter: 0/4, validation accuracies: [0.62323231 1.        ], average train loss: 41.028252, average train accuracy: 0.814453
# epoch: 31, iter: 0/4, validation accuracies: [0.62222222 1.        ], average train loss: 41.209919, average train accuracy: 0.814453
# epoch: 32, iter: 0/4, validation accuracies: [0.62626262 1.        ], average train loss: 40.113609, average train accuracy: 0.859375
# epoch: 33, iter: 0/4, validation accuracies: [0.62878789 1.        ], average train loss: 41.139545, average train accuracy: 0.826172
# epoch: 34, iter: 0/4, validation accuracies: [0.62777778 1.        ], average train loss: 40.103752, average train accuracy: 0.851562
# epoch: 35, iter: 0/4, validation accuracies: [0.62979798 1.        ], average train loss: 40.784157, average train accuracy: 0.835938
# epoch: 36, iter: 0/4, validation accuracies: [0.62777779 1.        ], average train loss: 40.491287, average train accuracy: 0.849609
# epoch: 37, iter: 0/4, validation accuracies: [0.62828282 1.        ], average train loss: 39.867374, average train accuracy: 0.873047
# epoch: 38, iter: 0/4, validation accuracies: [0.63232324 1.        ], average train loss: 40.813599, average train accuracy: 0.867188
# epoch: 39, iter: 0/4, validation accuracies: [0.63636363 1.        ], average train loss: 40.638447, average train accuracy: 0.861328
# epoch: 40, iter: 0/4, validation accuracies: [0.63030303 1.        ], average train loss: 40.732841, average train accuracy: 0.863281
# epochs: 40.000000, final train loss: 39.713844, validation accuracies: [0.63030303 1.        ]
# best epochs: 39.000000, best_avg: 0.640000, validation accuracies: [0.63636363 1.        ]
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.1,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# epoch: 1, iter: 0/4, validation accuracies: [0.6348485 1.       ], average train loss: 0.608789, average train accuracy: 0.806641
# epoch: 2, iter: 0/4, validation accuracies: [0.64494949 0.89999998], average train loss: 0.442021, average train accuracy: 0.865234
# epoch: 3, iter: 0/4, validation accuracies: [0.64141415 0.80000001], average train loss: 0.472429, average train accuracy: 0.837891
# epoch: 4, iter: 0/4, validation accuracies: [0.64393941 0.69999999], average train loss: 0.390354, average train accuracy: 0.871094
# epoch: 5, iter: 0/4, validation accuracies: [0.64696971 0.64999998], average train loss: 0.426415, average train accuracy: 0.863281
# epoch: 6, iter: 0/4, validation accuracies: [0.64444445 0.60000002], average train loss: 0.326044, average train accuracy: 0.910156
# epoch: 7, iter: 0/4, validation accuracies: [0.64696971 0.55000001], average train loss: 0.388010, average train accuracy: 0.871094
# epoch: 8, iter: 0/4, validation accuracies: [0.64595961 0.55000001], average train loss: 0.409635, average train accuracy: 0.867188
# epoch: 9, iter: 0/4, validation accuracies: [0.64595959 0.5       ], average train loss: 0.457435, average train accuracy: 0.878906
# epoch: 10, iter: 0/4, validation accuracies: [0.65050505 0.5       ], average train loss: 0.331998, average train accuracy: 0.886719
# epoch: 11, iter: 0/4, validation accuracies: [0.65050504 0.5       ], average train loss: 0.370957, average train accuracy: 0.890625
# epoch: 12, iter: 0/4, validation accuracies: [0.65151516 0.5       ], average train loss: 0.303890, average train accuracy: 0.906250
# epoch: 13, iter: 0/4, validation accuracies: [0.64949496 0.5       ], average train loss: 0.380320, average train accuracy: 0.871094
# epoch: 14, iter: 0/4, validation accuracies: [0.65050506 0.5       ], average train loss: 0.377168, average train accuracy: 0.890625
# epoch: 15, iter: 0/4, validation accuracies: [0.64949494 0.5       ], average train loss: 0.309571, average train accuracy: 0.916016
# epoch: 16, iter: 0/4, validation accuracies: [0.65151514 0.5       ], average train loss: 0.280785, average train accuracy: 0.914062
# epoch: 17, iter: 0/4, validation accuracies: [0.64646465 0.55000001], average train loss: 0.399263, average train accuracy: 0.884766
# epoch: 18, iter: 0/4, validation accuracies: [0.6489899 0.5      ], average train loss: 0.374508, average train accuracy: 0.876953
# epoch: 19, iter: 0/4, validation accuracies: [0.64747476 0.5       ], average train loss: 0.305212, average train accuracy: 0.898438
# epoch: 20, iter: 0/4, validation accuracies: [0.64696969 0.5       ], average train loss: 0.343161, average train accuracy: 0.898438
# epoch: 21, iter: 0/4, validation accuracies: [0.64848484 0.5       ], average train loss: 0.337956, average train accuracy: 0.896484
# epoch: 22, iter: 0/4, validation accuracies: [0.64797981 0.5       ], average train loss: 0.269413, average train accuracy: 0.908203
# epoch: 23, iter: 0/4, validation accuracies: [0.65 0.5 ], average train loss: 0.325156, average train accuracy: 0.900391
# epoch: 24, iter: 0/4, validation accuracies: [0.64191919 0.5       ], average train loss: 0.375577, average train accuracy: 0.882812
# epoch: 25, iter: 0/4, validation accuracies: [0.64242425 0.5       ], average train loss: 0.329868, average train accuracy: 0.904297
# epoch: 26, iter: 0/4, validation accuracies: [0.64292928 0.5       ], average train loss: 0.262460, average train accuracy: 0.914062
# epoch: 27, iter: 0/4, validation accuracies: [0.64494948 0.5       ], average train loss: 0.321959, average train accuracy: 0.892578
# epoch: 28, iter: 0/4, validation accuracies: [0.6439394  0.55000001], average train loss: 0.297235, average train accuracy: 0.906250
# epoch: 29, iter: 0/4, validation accuracies: [0.64444446 0.55000001], average train loss: 0.285459, average train accuracy: 0.914062
# epoch: 30, iter: 0/4, validation accuracies: [0.64090909 0.5       ], average train loss: 0.297707, average train accuracy: 0.902344
# epochs: 30.000000, final train loss: 0.308781, validation accuracies: [0.64090909 0.5       ]
# best epochs: 12.000000, best_avg: 0.650000, validation accuracies: [0.65151516 0.5       ]
# saving model T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.1,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1 at time step 280
# calculating penultimate output...
# time taken: %f 6.891799688339233
# saving penultimate output...
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.2,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# Restoring paramters from dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# epoch: 1, iter: 0/4, validation accuracies: [0.63080809 0.        ], average train loss: 41.906948, average train accuracy: 0.734375
# epoch: 2, iter: 0/4, validation accuracies: [0.56161617 0.40000001], average train loss: 41.625175, average train accuracy: 0.769531
# epoch: 3, iter: 0/4, validation accuracies: [0.45353536 0.60000002], average train loss: 40.613071, average train accuracy: 0.685547
# epoch: 4, iter: 0/4, validation accuracies: [0.59595959 0.34999999], average train loss: 41.272789, average train accuracy: 0.742188
# epoch: 5, iter: 0/4, validation accuracies: [0.57929293 0.34999999], average train loss: 41.575779, average train accuracy: 0.746094
# epoch: 6, iter: 0/4, validation accuracies: [0.5631313  0.85000002], average train loss: 40.781189, average train accuracy: 0.785156
# epoch: 7, iter: 0/4, validation accuracies: [0.5439394  0.85000002], average train loss: 41.233353, average train accuracy: 0.769531
# epoch: 8, iter: 0/4, validation accuracies: [0.56262625 0.85000002], average train loss: 41.380463, average train accuracy: 0.765625
# epoch: 9, iter: 0/4, validation accuracies: [0.55656565 0.85000002], average train loss: 40.929886, average train accuracy: 0.804688
# epoch: 10, iter: 0/4, validation accuracies: [0.53181818 0.94999999], average train loss: 40.924469, average train accuracy: 0.777344
# epoch: 11, iter: 0/4, validation accuracies: [0.57121212 1.        ], average train loss: 40.921173, average train accuracy: 0.773438
# epoch: 12, iter: 0/4, validation accuracies: [0.5878788  0.89999998], average train loss: 41.300419, average train accuracy: 0.822266
# epoch: 13, iter: 0/4, validation accuracies: [0.57575758 0.89999998], average train loss: 40.807968, average train accuracy: 0.775391
# epoch: 14, iter: 0/4, validation accuracies: [0.55959596 1.        ], average train loss: 41.395168, average train accuracy: 0.806641
# epoch: 15, iter: 0/4, validation accuracies: [0.57979797 0.94999999], average train loss: 40.862320, average train accuracy: 0.806641
# epoch: 16, iter: 0/4, validation accuracies: [0.59545453 1.        ], average train loss: 40.389744, average train accuracy: 0.802734
# epoch: 17, iter: 0/4, validation accuracies: [0.57121211 0.94999999], average train loss: 40.711689, average train accuracy: 0.806641
# epoch: 18, iter: 0/4, validation accuracies: [0.58333334 1.        ], average train loss: 41.242264, average train accuracy: 0.771484
# epoch: 19, iter: 0/4, validation accuracies: [0.55454547 0.94999999], average train loss: 40.745331, average train accuracy: 0.830078
# epoch: 20, iter: 0/4, validation accuracies: [0.58333335 0.94999999], average train loss: 41.656925, average train accuracy: 0.794922
# epoch: 21, iter: 0/4, validation accuracies: [0.60656565 0.94999999], average train loss: 41.180450, average train accuracy: 0.791016
# epoch: 22, iter: 0/4, validation accuracies: [0.61666668 0.94999999], average train loss: 40.710064, average train accuracy: 0.794922
# epoch: 23, iter: 0/4, validation accuracies: [0.62424241 1.        ], average train loss: 41.352135, average train accuracy: 0.845703
# epoch: 24, iter: 0/4, validation accuracies: [0.62474748 1.        ], average train loss: 41.102039, average train accuracy: 0.818359
# epoch: 25, iter: 0/4, validation accuracies: [0.61919191 1.        ], average train loss: 41.126778, average train accuracy: 0.847656
# epoch: 26, iter: 0/4, validation accuracies: [0.62373736 0.94999999], average train loss: 40.794331, average train accuracy: 0.824219
# epoch: 27, iter: 0/4, validation accuracies: [0.62929293 0.94999999], average train loss: 40.898571, average train accuracy: 0.810547
# epoch: 28, iter: 0/4, validation accuracies: [0.62979798 0.94999999], average train loss: 41.285114, average train accuracy: 0.845703
# epoch: 29, iter: 0/4, validation accuracies: [0.62929292 0.94999999], average train loss: 39.871220, average train accuracy: 0.849609
# epoch: 30, iter: 0/4, validation accuracies: [0.63535354 0.94999999], average train loss: 40.624527, average train accuracy: 0.816406
# epoch: 31, iter: 0/4, validation accuracies: [0.63333332 0.94999999], average train loss: 40.695366, average train accuracy: 0.857422
# epoch: 32, iter: 0/4, validation accuracies: [0.63434343 0.94999999], average train loss: 40.049690, average train accuracy: 0.847656
# epoch: 33, iter: 0/4, validation accuracies: [0.6348485  0.94999999], average train loss: 40.677769, average train accuracy: 0.826172
# epoch: 34, iter: 0/4, validation accuracies: [0.63232323 0.94999999], average train loss: 40.685516, average train accuracy: 0.849609
# epoch: 35, iter: 0/4, validation accuracies: [0.63383839 0.94999999], average train loss: 40.661438, average train accuracy: 0.826172
# epoch: 36, iter: 0/4, validation accuracies: [0.63838384 0.94999999], average train loss: 40.199768, average train accuracy: 0.853516
# epoch: 37, iter: 0/4, validation accuracies: [0.63636364 0.94999999], average train loss: 41.390251, average train accuracy: 0.832031
# epoch: 38, iter: 0/4, validation accuracies: [0.63434342 0.94999999], average train loss: 39.720394, average train accuracy: 0.843750
# epoch: 39, iter: 0/4, validation accuracies: [0.63383838 0.94999999], average train loss: 40.567490, average train accuracy: 0.863281
# epoch: 40, iter: 0/4, validation accuracies: [0.63131314 0.94999999], average train loss: 40.073463, average train accuracy: 0.830078
# epochs: 40.000000, final train loss: 39.439148, validation accuracies: [0.63131314 0.94999999]
# best epochs: 36.000000, best_avg: 0.641500, validation accuracies: [0.63838384 0.94999999]
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.2,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# epoch: 1, iter: 0/4, validation accuracies: [0.63383839 0.94999999], average train loss: 0.545558, average train accuracy: 0.820312
# epoch: 2, iter: 0/4, validation accuracies: [0.64191919 0.85000002], average train loss: 0.508405, average train accuracy: 0.841797
# epoch: 3, iter: 0/4, validation accuracies: [0.64242424 0.85000002], average train loss: 0.444707, average train accuracy: 0.851562
# epoch: 4, iter: 0/4, validation accuracies: [0.64696968 0.75      ], average train loss: 0.442338, average train accuracy: 0.853516
# epoch: 5, iter: 0/4, validation accuracies: [0.65       0.64999998], average train loss: 0.480593, average train accuracy: 0.833984
# epoch: 6, iter: 0/4, validation accuracies: [0.6520202  0.64999998], average train loss: 0.401727, average train accuracy: 0.871094
# epoch: 7, iter: 0/4, validation accuracies: [0.65353536 0.64999998], average train loss: 0.347900, average train accuracy: 0.884766
# epoch: 8, iter: 0/4, validation accuracies: [0.65454546 0.60000002], average train loss: 0.428758, average train accuracy: 0.855469
# epoch: 9, iter: 0/4, validation accuracies: [0.65555557 0.60000002], average train loss: 0.403155, average train accuracy: 0.873047
# epoch: 10, iter: 0/4, validation accuracies: [0.65404041 0.60000002], average train loss: 0.396736, average train accuracy: 0.857422
# epoch: 11, iter: 0/4, validation accuracies: [0.65151516 0.60000002], average train loss: 0.361811, average train accuracy: 0.896484
# epoch: 12, iter: 0/4, validation accuracies: [0.6489899  0.60000002], average train loss: 0.309311, average train accuracy: 0.902344
# epoch: 13, iter: 0/4, validation accuracies: [0.64848485 0.60000002], average train loss: 0.314677, average train accuracy: 0.900391
# epoch: 14, iter: 0/4, validation accuracies: [0.6550505  0.60000002], average train loss: 0.370080, average train accuracy: 0.867188
# epoch: 15, iter: 0/4, validation accuracies: [0.65505051 0.60000002], average train loss: 0.271700, average train accuracy: 0.917969
# epoch: 16, iter: 0/4, validation accuracies: [0.64949494 0.60000002], average train loss: 0.266378, average train accuracy: 0.921875
# epoch: 17, iter: 0/4, validation accuracies: [0.65151514 0.60000002], average train loss: 0.360620, average train accuracy: 0.886719
# epoch: 18, iter: 0/4, validation accuracies: [0.65202021 0.60000002], average train loss: 0.277080, average train accuracy: 0.900391
# epoch: 19, iter: 0/4, validation accuracies: [0.65404041 0.60000002], average train loss: 0.285573, average train accuracy: 0.921875
# epoch: 20, iter: 0/4, validation accuracies: [0.6540404  0.60000002], average train loss: 0.269491, average train accuracy: 0.921875
# epoch: 21, iter: 0/4, validation accuracies: [0.65656565 0.60000002], average train loss: 0.301013, average train accuracy: 0.912109
# epoch: 22, iter: 0/4, validation accuracies: [0.65555557 0.60000002], average train loss: 0.300098, average train accuracy: 0.898438
# epoch: 23, iter: 0/4, validation accuracies: [0.65757575 0.60000002], average train loss: 0.323641, average train accuracy: 0.912109
# epoch: 24, iter: 0/4, validation accuracies: [0.65505049 0.60000002], average train loss: 0.312919, average train accuracy: 0.900391
# epoch: 25, iter: 0/4, validation accuracies: [0.65707072 0.60000002], average train loss: 0.246735, average train accuracy: 0.931641
# epoch: 26, iter: 0/4, validation accuracies: [0.65353536 0.60000002], average train loss: 0.314753, average train accuracy: 0.902344
# epoch: 27, iter: 0/4, validation accuracies: [0.65606062 0.60000002], average train loss: 0.309512, average train accuracy: 0.923828
# epoch: 28, iter: 0/4, validation accuracies: [0.65353535 0.60000002], average train loss: 0.272784, average train accuracy: 0.921875
# epoch: 29, iter: 0/4, validation accuracies: [0.65353535 0.60000002], average train loss: 0.282467, average train accuracy: 0.914062
# epoch: 30, iter: 0/4, validation accuracies: [0.65606062 0.60000002], average train loss: 0.268084, average train accuracy: 0.921875
# epochs: 30.000000, final train loss: 0.321170, validation accuracies: [0.65606062 0.60000002]
# best epochs: 23.000000, best_avg: 0.657000, validation accuracies: [0.65757575 0.60000002]
# saving model T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.2,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1 at time step 280
# calculating penultimate output...
# time taken: %f 6.845510005950928
# saving penultimate output...
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.4,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# Restoring paramters from dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# epoch: 1, iter: 0/4, validation accuracies: [0.64141414 0.        ], average train loss: 42.001350, average train accuracy: 0.769531
# epoch: 2, iter: 0/4, validation accuracies: [0.58333333 0.15000001], average train loss: 41.496777, average train accuracy: 0.769531
# epoch: 3, iter: 0/4, validation accuracies: [0.39595959 0.85000002], average train loss: 40.307423, average train accuracy: 0.728516
# epoch: 4, iter: 0/4, validation accuracies: [0.589899   0.34999999], average train loss: 40.602806, average train accuracy: 0.710938
# epoch: 5, iter: 0/4, validation accuracies: [0.60050504 0.25      ], average train loss: 41.207310, average train accuracy: 0.746094
# epoch: 6, iter: 0/4, validation accuracies: [0.59898991 0.64999998], average train loss: 39.930195, average train accuracy: 0.755859
# epoch: 7, iter: 0/4, validation accuracies: [0.53383839 0.89999998], average train loss: 41.836823, average train accuracy: 0.804688
# epoch: 8, iter: 0/4, validation accuracies: [0.52626264 0.85000002], average train loss: 39.867668, average train accuracy: 0.767578
# epoch: 9, iter: 0/4, validation accuracies: [0.56919191 0.80000001], average train loss: 41.092396, average train accuracy: 0.773438
# epoch: 10, iter: 0/4, validation accuracies: [0.56868687 0.75      ], average train loss: 41.747921, average train accuracy: 0.787109
# epoch: 11, iter: 0/4, validation accuracies: [0.56010101 0.85000002], average train loss: 41.395195, average train accuracy: 0.808594
# epoch: 12, iter: 0/4, validation accuracies: [0.54949495 0.89999998], average train loss: 41.697975, average train accuracy: 0.785156
# epoch: 13, iter: 0/4, validation accuracies: [0.56717172 1.        ], average train loss: 40.364895, average train accuracy: 0.820312
# epoch: 14, iter: 0/4, validation accuracies: [0.57424244 0.89999998], average train loss: 41.813618, average train accuracy: 0.802734
# epoch: 15, iter: 0/4, validation accuracies: [0.59747476 0.85000002], average train loss: 40.482464, average train accuracy: 0.798828
# epoch: 16, iter: 0/4, validation accuracies: [0.58535354 1.        ], average train loss: 41.604012, average train accuracy: 0.796875
# epoch: 17, iter: 0/4, validation accuracies: [0.57424242 0.94999999], average train loss: 40.626389, average train accuracy: 0.812500
# epoch: 18, iter: 0/4, validation accuracies: [0.57575757 0.89999998], average train loss: 41.551750, average train accuracy: 0.820312
# epoch: 19, iter: 0/4, validation accuracies: [0.59191919 1.        ], average train loss: 40.823334, average train accuracy: 0.824219
# epoch: 20, iter: 0/4, validation accuracies: [0.59797979 0.94999999], average train loss: 40.889114, average train accuracy: 0.839844
# epoch: 21, iter: 0/4, validation accuracies: [0.6141414 1.       ], average train loss: 40.713181, average train accuracy: 0.810547
# epoch: 22, iter: 0/4, validation accuracies: [0.62474748 1.        ], average train loss: 41.511799, average train accuracy: 0.826172
# epoch: 23, iter: 0/4, validation accuracies: [0.62777778 1.        ], average train loss: 41.498276, average train accuracy: 0.816406
# epoch: 24, iter: 0/4, validation accuracies: [0.62272727 1.        ], average train loss: 40.587460, average train accuracy: 0.835938
# epoch: 25, iter: 0/4, validation accuracies: [0.62727272 1.        ], average train loss: 40.747437, average train accuracy: 0.843750
# epoch: 26, iter: 0/4, validation accuracies: [0.63434344 1.        ], average train loss: 39.800117, average train accuracy: 0.853516
# epoch: 27, iter: 0/4, validation accuracies: [0.63686868 1.        ], average train loss: 40.582710, average train accuracy: 0.820312
# epoch: 28, iter: 0/4, validation accuracies: [0.63989899 1.        ], average train loss: 41.514576, average train accuracy: 0.837891
# epoch: 29, iter: 0/4, validation accuracies: [0.63939394 0.94999999], average train loss: 40.640759, average train accuracy: 0.861328
# epoch: 30, iter: 0/4, validation accuracies: [0.639899   0.94999999], average train loss: 40.365570, average train accuracy: 0.828125
# epoch: 31, iter: 0/4, validation accuracies: [0.64191918 0.94999999], average train loss: 41.191170, average train accuracy: 0.837891
# epoch: 32, iter: 0/4, validation accuracies: [0.639899 1.      ], average train loss: 41.235104, average train accuracy: 0.833984
# epoch: 33, iter: 0/4, validation accuracies: [0.63686868 1.        ], average train loss: 41.341137, average train accuracy: 0.835938
# epoch: 34, iter: 0/4, validation accuracies: [0.63989899 1.        ], average train loss: 39.772942, average train accuracy: 0.839844
# epoch: 35, iter: 0/4, validation accuracies: [0.63888889 1.        ], average train loss: 41.097073, average train accuracy: 0.839844
# epoch: 36, iter: 0/4, validation accuracies: [0.63636363 1.        ], average train loss: 40.615238, average train accuracy: 0.837891
# epoch: 37, iter: 0/4, validation accuracies: [0.63686868 1.        ], average train loss: 40.690086, average train accuracy: 0.822266
# epoch: 38, iter: 0/4, validation accuracies: [0.6358586 1.       ], average train loss: 40.383583, average train accuracy: 0.857422
# epoch: 39, iter: 0/4, validation accuracies: [0.6409091 1.       ], average train loss: 40.088814, average train accuracy: 0.845703
# epoch: 40, iter: 0/4, validation accuracies: [0.64242425 1.        ], average train loss: 40.722946, average train accuracy: 0.826172
# epochs: 40.000000, final train loss: 41.188274, validation accuracies: [0.64242425 1.        ]
# best epochs: 40.000000, best_avg: 0.646000, validation accuracies: [0.64242425 1.        ]
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.4,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# epoch: 1, iter: 0/4, validation accuracies: [0.64494951 1.        ], average train loss: 0.605079, average train accuracy: 0.808594
# epoch: 2, iter: 0/4, validation accuracies: [0.65151516 0.89999998], average train loss: 0.479750, average train accuracy: 0.837891
# epoch: 3, iter: 0/4, validation accuracies: [0.65151515 0.75      ], average train loss: 0.422184, average train accuracy: 0.865234
# epoch: 4, iter: 0/4, validation accuracies: [0.6540404  0.64999998], average train loss: 0.403084, average train accuracy: 0.863281
# epoch: 5, iter: 0/4, validation accuracies: [0.65202021 0.64999998], average train loss: 0.357250, average train accuracy: 0.876953
# epoch: 6, iter: 0/4, validation accuracies: [0.6530303  0.60000002], average train loss: 0.371479, average train accuracy: 0.878906
# epoch: 7, iter: 0/4, validation accuracies: [0.65303031 0.55000001], average train loss: 0.369896, average train accuracy: 0.875000
# epoch: 8, iter: 0/4, validation accuracies: [0.65505051 0.55000001], average train loss: 0.311189, average train accuracy: 0.896484
# epoch: 9, iter: 0/4, validation accuracies: [0.6570707  0.55000001], average train loss: 0.393632, average train accuracy: 0.876953
# epoch: 10, iter: 0/4, validation accuracies: [0.65757576 0.5       ], average train loss: 0.267846, average train accuracy: 0.921875
# epoch: 11, iter: 0/4, validation accuracies: [0.65959596 0.55000001], average train loss: 0.350721, average train accuracy: 0.900391
# epoch: 12, iter: 0/4, validation accuracies: [0.6580808  0.55000001], average train loss: 0.313189, average train accuracy: 0.884766
# epoch: 13, iter: 0/4, validation accuracies: [0.65656565 0.5       ], average train loss: 0.320846, average train accuracy: 0.890625
# epoch: 14, iter: 0/4, validation accuracies: [0.65808082 0.5       ], average train loss: 0.287225, average train accuracy: 0.908203
# epoch: 15, iter: 0/4, validation accuracies: [0.66161616 0.5       ], average train loss: 0.284668, average train accuracy: 0.912109
# epoch: 16, iter: 0/4, validation accuracies: [0.66363637 0.5       ], average train loss: 0.259211, average train accuracy: 0.927734
# epoch: 17, iter: 0/4, validation accuracies: [0.65858587 0.5       ], average train loss: 0.286837, average train accuracy: 0.906250
# epoch: 18, iter: 0/4, validation accuracies: [0.66212121 0.44999999], average train loss: 0.294483, average train accuracy: 0.900391
# epoch: 19, iter: 0/4, validation accuracies: [0.65959596 0.44999999], average train loss: 0.329090, average train accuracy: 0.910156
# epoch: 20, iter: 0/4, validation accuracies: [0.65959597 0.5       ], average train loss: 0.285978, average train accuracy: 0.906250
# epoch: 21, iter: 0/4, validation accuracies: [0.6621212  0.55000001], average train loss: 0.254667, average train accuracy: 0.925781
# epoch: 22, iter: 0/4, validation accuracies: [0.66161616 0.55000001], average train loss: 0.318921, average train accuracy: 0.896484
# epoch: 23, iter: 0/4, validation accuracies: [0.66212122 0.55000001], average train loss: 0.250185, average train accuracy: 0.917969
# epoch: 24, iter: 0/4, validation accuracies: [0.66060606 0.44999999], average train loss: 0.327307, average train accuracy: 0.892578
# epoch: 25, iter: 0/4, validation accuracies: [0.66010102 0.55000001], average train loss: 0.230013, average train accuracy: 0.927734
# epoch: 26, iter: 0/4, validation accuracies: [0.65757575 0.55000001], average train loss: 0.268359, average train accuracy: 0.914062
# epoch: 27, iter: 0/4, validation accuracies: [0.65454545 0.5       ], average train loss: 0.248403, average train accuracy: 0.927734
# epoch: 28, iter: 0/4, validation accuracies: [0.65454545 0.55000001], average train loss: 0.283404, average train accuracy: 0.902344
# epoch: 29, iter: 0/4, validation accuracies: [0.65555556 0.60000002], average train loss: 0.300723, average train accuracy: 0.910156
# epoch: 30, iter: 0/4, validation accuracies: [0.65656566 0.5       ], average train loss: 0.275113, average train accuracy: 0.914062
# epochs: 30.000000, final train loss: 0.298224, validation accuracies: [0.65656566 0.5       ]
# best epochs: 16.000000, best_avg: 0.662000, validation accuracies: [0.66363637 0.5       ]
# saving model T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.4,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1 at time step 280
# calculating penultimate output...
# time taken: %f 6.892804861068726
# saving penultimate output...
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.5,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# Restoring paramters from dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# epoch: 1, iter: 0/4, validation accuracies: [0.63636363 0.        ], average train loss: 40.917278, average train accuracy: 0.785156
# epoch: 2, iter: 0/4, validation accuracies: [0.60757577 0.05      ], average train loss: 42.256039, average train accuracy: 0.742188
# epoch: 3, iter: 0/4, validation accuracies: [0.42777777 0.85000002], average train loss: 40.710438, average train accuracy: 0.722656
# epoch: 4, iter: 0/4, validation accuracies: [0.58181819 0.40000001], average train loss: 41.272144, average train accuracy: 0.689453
# epoch: 5, iter: 0/4, validation accuracies: [0.59141413 0.1       ], average train loss: 40.532337, average train accuracy: 0.761719
# epoch: 6, iter: 0/4, validation accuracies: [0.59444444 0.60000002], average train loss: 40.168175, average train accuracy: 0.746094
# epoch: 7, iter: 0/4, validation accuracies: [0.55404039 0.94999999], average train loss: 42.541321, average train accuracy: 0.775391
# epoch: 8, iter: 0/4, validation accuracies: [0.55707071 0.89999998], average train loss: 41.450840, average train accuracy: 0.753906
# epoch: 9, iter: 0/4, validation accuracies: [0.59646464 0.75      ], average train loss: 41.357224, average train accuracy: 0.806641
# epoch: 10, iter: 0/4, validation accuracies: [0.59848485 0.75      ], average train loss: 41.617950, average train accuracy: 0.769531
# epoch: 11, iter: 0/4, validation accuracies: [0.55151515 0.80000001], average train loss: 40.839218, average train accuracy: 0.796875
# epoch: 12, iter: 0/4, validation accuracies: [0.5590909  0.94999999], average train loss: 41.087307, average train accuracy: 0.796875
# epoch: 13, iter: 0/4, validation accuracies: [0.55909091 0.75      ], average train loss: 41.324226, average train accuracy: 0.802734
# epoch: 14, iter: 0/4, validation accuracies: [0.56969696 0.69999999], average train loss: 40.930992, average train accuracy: 0.808594
# epoch: 15, iter: 0/4, validation accuracies: [0.57222222 0.94999999], average train loss: 41.626030, average train accuracy: 0.750000
# epoch: 16, iter: 0/4, validation accuracies: [0.57272728 0.94999999], average train loss: 41.050488, average train accuracy: 0.787109
# epoch: 17, iter: 0/4, validation accuracies: [0.57525253 0.80000001], average train loss: 40.950943, average train accuracy: 0.810547
# epoch: 18, iter: 0/4, validation accuracies: [0.56363637 0.85000002], average train loss: 41.023201, average train accuracy: 0.820312
# epoch: 19, iter: 0/4, validation accuracies: [0.57929293 0.89999998], average train loss: 42.738220, average train accuracy: 0.771484
# epoch: 20, iter: 0/4, validation accuracies: [0.55505049 0.94999999], average train loss: 40.957470, average train accuracy: 0.812500
# epoch: 21, iter: 0/4, validation accuracies: [0.58434344 0.89999998], average train loss: 40.774086, average train accuracy: 0.775391
# ...
# epochs: 40.000000, final train loss: 40.456161, validation accuracies: [0.63888889 1.        ]
# best epochs: 38.000000, best_avg: 0.643500, validation accuracies: [0.639899 1.      ]
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.7,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# epoch: 1, iter: 0/4, validation accuracies: [0.63787879 0.94999999], average train loss: 0.618150, average train accuracy: 0.820312
# epoch: 2, iter: 0/4, validation accuracies: [0.64090909 0.85000002], average train loss: 0.467700, average train accuracy: 0.833984
# epoch: 3, iter: 0/4, validation accuracies: [0.64343433 0.75      ], average train loss: 0.516483, average train accuracy: 0.833984
# epoch: 4, iter: 0/4, validation accuracies: [0.64141414 0.75      ], average train loss: 0.505278, average train accuracy: 0.830078
# epoch: 5, iter: 0/4, validation accuracies: [0.64141414 0.64999998], average train loss: 0.457764, average train accuracy: 0.841797
# epoch: 6, iter: 0/4, validation accuracies: [0.6419192  0.64999998], average train loss: 0.487867, average train accuracy: 0.849609
# epoch: 7, iter: 0/4, validation accuracies: [0.6449495  0.64999998], average train loss: 0.404011, average train accuracy: 0.888672
# epoch: 8, iter: 0/4, validation accuracies: [0.6459596  0.60000002], average train loss: 0.338723, average train accuracy: 0.884766
# epoch: 9, iter: 0/4, validation accuracies: [0.64494948 0.60000002], average train loss: 0.317614, average train accuracy: 0.894531
# epoch: 10, iter: 0/4, validation accuracies: [0.64343436 0.55000001], average train loss: 0.369520, average train accuracy: 0.878906
# epoch: 11, iter: 0/4, validation accuracies: [0.64343436 0.55000001], average train loss: 0.387518, average train accuracy: 0.871094
# epoch: 12, iter: 0/4, validation accuracies: [0.64343433 0.5       ], average train loss: 0.288941, average train accuracy: 0.896484
# epoch: 13, iter: 0/4, validation accuracies: [0.64444444 0.5       ], average train loss: 0.388604, average train accuracy: 0.878906
# epoch: 14, iter: 0/4, validation accuracies: [0.64444444 0.5       ], average train loss: 0.329326, average train accuracy: 0.876953
# epoch: 15, iter: 0/4, validation accuracies: [0.64393939 0.5       ], average train loss: 0.316031, average train accuracy: 0.902344
# epoch: 16, iter: 0/4, validation accuracies: [0.64595959 0.55000001], average train loss: 0.320465, average train accuracy: 0.894531
# epoch: 17, iter: 0/4, validation accuracies: [0.6439394  0.55000001], average train loss: 0.292942, average train accuracy: 0.902344
# epoch: 18, iter: 0/4, validation accuracies: [0.64242424 0.55000001], average train loss: 0.333952, average train accuracy: 0.888672
# epoch: 19, iter: 0/4, validation accuracies: [0.64646464 0.55000001], average train loss: 0.307115, average train accuracy: 0.906250
# epoch: 20, iter: 0/4, validation accuracies: [0.64646465 0.60000002], average train loss: 0.350410, average train accuracy: 0.894531
# epoch: 21, iter: 0/4, validation accuracies: [0.64595958 0.60000002], average train loss: 0.320132, average train accuracy: 0.896484
# epoch: 22, iter: 0/4, validation accuracies: [0.64494948 0.60000002], average train loss: 0.289826, average train accuracy: 0.923828
# epoch: 23, iter: 0/4, validation accuracies: [0.64343436 0.60000002], average train loss: 0.349716, average train accuracy: 0.902344
# epoch: 24, iter: 0/4, validation accuracies: [0.64747475 0.55000001], average train loss: 0.282595, average train accuracy: 0.921875
# epoch: 25, iter: 0/4, validation accuracies: [0.64747474 0.55000001], average train loss: 0.348673, average train accuracy: 0.882812
# epoch: 26, iter: 0/4, validation accuracies: [0.64949494 0.60000002], average train loss: 0.249424, average train accuracy: 0.927734
# epoch: 27, iter: 0/4, validation accuracies: [0.64848483 0.55000001], average train loss: 0.267787, average train accuracy: 0.919922
# epoch: 28, iter: 0/4, validation accuracies: [0.64545454 0.55000001], average train loss: 0.386337, average train accuracy: 0.873047
# epoch: 29, iter: 0/4, validation accuracies: [0.64848485 0.55000001], average train loss: 0.269967, average train accuracy: 0.921875
# epoch: 30, iter: 0/4, validation accuracies: [0.65050504 0.60000002], average train loss: 0.306297, average train accuracy: 0.906250
# epochs: 30.000000, final train loss: 0.264954, validation accuracies: [0.65050504 0.60000002]
# best epochs: 30.000000, best_avg: 0.650000, validation accuracies: [0.65050504 0.60000002]
# saving model T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.7,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1 at time step 280
# calculating penultimate output...
# time taken: %f 6.945967435836792
# saving penultimate output...
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=1.0,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# Restoring paramters from dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/dropout_hidden_prob=0.9,dropout_input_prob=0.9,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=1.0,task=0.ckpt-26040
# epoch: 1, iter: 0/4, validation accuracies: [0.64595959 0.        ], average train loss: 40.019279, average train accuracy: 0.785156
# epoch: 2, iter: 0/4, validation accuracies: [0.61060606 0.15000001], average train loss: 40.705406, average train accuracy: 0.765625
# epoch: 3, iter: 0/4, validation accuracies: [0.40656566 0.85000002], average train loss: 40.838657, average train accuracy: 0.755859
# epoch: 4, iter: 0/4, validation accuracies: [0.5611111  0.34999999], average train loss: 40.606182, average train accuracy: 0.685547
# epoch: 5, iter: 0/4, validation accuracies: [0.59292929 0.15000001], average train loss: 40.970573, average train accuracy: 0.761719
# epoch: 6, iter: 0/4, validation accuracies: [0.58484849 0.60000002], average train loss: 40.863899, average train accuracy: 0.800781
# epoch: 7, iter: 0/4, validation accuracies: [0.52020202 0.94999999], average train loss: 40.813427, average train accuracy: 0.779297
# epoch: 8, iter: 0/4, validation accuracies: [0.56363637 0.89999998], average train loss: 41.369434, average train accuracy: 0.753906
# epoch: 9, iter: 0/4, validation accuracies: [0.59343435 0.75      ], average train loss: 40.887741, average train accuracy: 0.814453
# epoch: 10, iter: 0/4, validation accuracies: [0.57878788 0.80000001], average train loss: 40.405777, average train accuracy: 0.777344
# epoch: 11, iter: 0/4, validation accuracies: [0.58535353 0.89999998], average train loss: 40.963669, average train accuracy: 0.812500
# epoch: 12, iter: 0/4, validation accuracies: [0.57020202 0.85000002], average train loss: 40.661072, average train accuracy: 0.828125
# epoch: 13, iter: 0/4, validation accuracies: [0.57424243 0.94999999], average train loss: 40.861053, average train accuracy: 0.773438
# epoch: 14, iter: 0/4, validation accuracies: [0.58232324 0.85000002], average train loss: 41.875061, average train accuracy: 0.781250
# epoch: 15, iter: 0/4, validation accuracies: [0.57676768 0.94999999], average train loss: 41.121452, average train accuracy: 0.800781
# epoch: 16, iter: 0/4, validation accuracies: [0.58232322 1.        ], average train loss: 40.677094, average train accuracy: 0.822266
# epoch: 17, iter: 0/4, validation accuracies: [0.58080809 0.94999999], average train loss: 40.903938, average train accuracy: 0.820312
# epoch: 18, iter: 0/4, validation accuracies: [0.57929292 1.        ], average train loss: 40.543007, average train accuracy: 0.785156
# epoch: 19, iter: 0/4, validation accuracies: [0.59242424 1.        ], average train loss: 40.899673, average train accuracy: 0.804688
# epoch: 20, iter: 0/4, validation accuracies: [0.5919192  0.94999999], average train loss: 41.178272, average train accuracy: 0.800781
# epoch: 21, iter: 0/4, validation accuracies: [0.61515152 1.        ], average train loss: 39.976128, average train accuracy: 0.832031
# epoch: 22, iter: 0/4, validation accuracies: [0.62626263 1.        ], average train loss: 40.501007, average train accuracy: 0.826172
# epoch: 23, iter: 0/4, validation accuracies: [0.61919191 1.        ], average train loss: 40.108093, average train accuracy: 0.841797
# epoch: 24, iter: 0/4, validation accuracies: [0.6151515 1.       ], average train loss: 40.946205, average train accuracy: 0.843750
# epoch: 25, iter: 0/4, validation accuracies: [0.61868688 1.        ], average train loss: 40.864254, average train accuracy: 0.826172
# epoch: 26, iter: 0/4, validation accuracies: [0.62424242 1.        ], average train loss: 40.895420, average train accuracy: 0.849609
# epoch: 27, iter: 0/4, validation accuracies: [0.62777777 0.94999999], average train loss: 40.881905, average train accuracy: 0.832031
# epoch: 28, iter: 0/4, validation accuracies: [0.62727274 0.94999999], average train loss: 40.734001, average train accuracy: 0.828125
# epoch: 29, iter: 0/4, validation accuracies: [0.62323233 0.94999999], average train loss: 39.618492, average train accuracy: 0.857422
# epoch: 30, iter: 0/4, validation accuracies: [0.62575759 0.94999999], average train loss: 40.147713, average train accuracy: 0.861328
# epoch: 31, iter: 0/4, validation accuracies: [0.62676769 0.94999999], average train loss: 40.455254, average train accuracy: 0.843750
# epoch: 32, iter: 0/4, validation accuracies: [0.62878789 0.94999999], average train loss: 39.307549, average train accuracy: 0.824219
# epoch: 33, iter: 0/4, validation accuracies: [0.62979799 1.        ], average train loss: 41.286266, average train accuracy: 0.835938
# epoch: 34, iter: 0/4, validation accuracies: [0.63080809 1.        ], average train loss: 39.866726, average train accuracy: 0.853516
# epoch: 35, iter: 0/4, validation accuracies: [0.63282828 1.        ], average train loss: 41.432190, average train accuracy: 0.849609
# epoch: 36, iter: 0/4, validation accuracies: [0.63282829 1.        ], average train loss: 40.339699, average train accuracy: 0.839844
# epoch: 37, iter: 0/4, validation accuracies: [0.62929292 1.        ], average train loss: 39.242439, average train accuracy: 0.880859
# epoch: 38, iter: 0/4, validation accuracies: [0.63030304 1.        ], average train loss: 40.534599, average train accuracy: 0.847656
# epoch: 39, iter: 0/4, validation accuracies: [0.63333334 1.        ], average train loss: 41.279434, average train accuracy: 0.839844
# epoch: 40, iter: 0/4, validation accuracies: [0.63030302 1.        ], average train loss: 40.448082, average train accuracy: 0.810547
# epochs: 40.000000, final train loss: 40.860878, validation accuracies: [0.63030302 1.        ]
# best epochs: 1.000000, best_avg: 0.639500, validation accuracies: [0.64595959 0.        ]
# Training with T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=1.0,fisher_multiplier=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1
# epoch: 1, iter: 0/4, validation accuracies: [0.63434344 1.        ], average train loss: 0.463160, average train accuracy: 0.843750
# epoch: 2, iter: 0/4, validation accuracies: [0.63535352 0.94999999], average train loss: 0.526811, average train accuracy: 0.847656
# epoch: 3, iter: 0/4, validation accuracies: [0.6439394  0.94999999], average train loss: 0.464614, average train accuracy: 0.841797
# epoch: 4, iter: 0/4, validation accuracies: [0.6479798  0.85000002], average train loss: 0.418904, average train accuracy: 0.888672
# epoch: 5, iter: 0/4, validation accuracies: [0.64747475 0.69999999], average train loss: 0.416008, average train accuracy: 0.873047
# epoch: 6, iter: 0/4, validation accuracies: [0.64646466 0.64999998], average train loss: 0.397739, average train accuracy: 0.871094
# epoch: 7, iter: 0/4, validation accuracies: [0.65050504 0.64999998], average train loss: 0.326557, average train accuracy: 0.888672
# epoch: 8, iter: 0/4, validation accuracies: [0.64646465 0.60000002], average train loss: 0.358443, average train accuracy: 0.886719
# epoch: 9, iter: 0/4, validation accuracies: [0.64797979 0.60000002], average train loss: 0.390562, average train accuracy: 0.859375
# epoch: 10, iter: 0/4, validation accuracies: [0.64595959 0.60000002], average train loss: 0.375350, average train accuracy: 0.888672
# epoch: 11, iter: 0/4, validation accuracies: [0.6479798  0.64999998], average train loss: 0.315728, average train accuracy: 0.896484
# epoch: 12, iter: 0/4, validation accuracies: [0.64545454 0.60000002], average train loss: 0.353963, average train accuracy: 0.880859
# epoch: 13, iter: 0/4, validation accuracies: [0.6479798  0.64999998], average train loss: 0.294285, average train accuracy: 0.894531
# epoch: 14, iter: 0/4, validation accuracies: [0.6540404  0.64999998], average train loss: 0.318168, average train accuracy: 0.902344
# epoch: 15, iter: 0/4, validation accuracies: [0.65151516 0.64999998], average train loss: 0.312275, average train accuracy: 0.908203
# epoch: 16, iter: 0/4, validation accuracies: [0.64999999 0.64999998], average train loss: 0.314325, average train accuracy: 0.894531
# epoch: 17, iter: 0/4, validation accuracies: [0.6449495  0.64999998], average train loss: 0.315121, average train accuracy: 0.898438
# epoch: 18, iter: 0/4, validation accuracies: [0.64646464 0.64999998], average train loss: 0.306238, average train accuracy: 0.919922
# epoch: 19, iter: 0/4, validation accuracies: [0.65151514 0.64999998], average train loss: 0.314454, average train accuracy: 0.898438
# epoch: 20, iter: 0/4, validation accuracies: [0.6540404  0.64999998], average train loss: 0.324644, average train accuracy: 0.902344
# epoch: 21, iter: 0/4, validation accuracies: [0.6550505  0.69999999], average train loss: 0.313248, average train accuracy: 0.900391
# epoch: 22, iter: 0/4, validation accuracies: [0.65404042 0.69999999], average train loss: 0.250505, average train accuracy: 0.917969
# epoch: 23, iter: 0/4, validation accuracies: [0.65151516 0.64999998], average train loss: 0.258032, average train accuracy: 0.927734
# epoch: 24, iter: 0/4, validation accuracies: [0.64949496 0.69999999], average train loss: 0.285535, average train accuracy: 0.916016
# epoch: 25, iter: 0/4, validation accuracies: [0.6479798  0.69999999], average train loss: 0.250703, average train accuracy: 0.916016
# epoch: 26, iter: 0/4, validation accuracies: [0.65202019 0.69999999], average train loss: 0.315951, average train accuracy: 0.904297
# epoch: 27, iter: 0/4, validation accuracies: [0.64797981 0.64999998], average train loss: 0.320383, average train accuracy: 0.908203
# epoch: 28, iter: 0/4, validation accuracies: [0.64999999 0.64999998], average train loss: 0.330227, average train accuracy: 0.921875
# epoch: 29, iter: 0/4, validation accuracies: [0.65050505 0.64999998], average train loss: 0.346618, average train accuracy: 0.898438
# epoch: 30, iter: 0/4, validation accuracies: [0.65050505 0.69999999], average train loss: 0.277341, average train accuracy: 0.919922
# epochs: 30.000000, final train loss: 0.357373, validation accuracies: [0.65050505 0.69999999]
# best epochs: 21.000000, best_avg: 0.655500, validation accuracies: [0.6550505  0.69999999]
# saving model T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=1.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1 at time step 280
# calculating penultimate output...
# time taken: %f 6.841074705123901
# saving penultimate output...

# %%
plt.rcParams['figure.figsize'] = [5, 5]
best_hparams_tuple = tuner.hparamsDictToTuple(hparams[best_hparams_index], tuner.tuner_hparams)
cur_res = tuner.results_list[t][best_hparams_tuple]
x = np.arange(0, cur_res[0]['total_updates'] + cur_res[1]['total_updates'], cur_res[0]['updates_per_epoch'])
cur_best_avg = cur_res[1]['best_avg']
cur_best_epoch = cur_res[1]['best_epoch']
updates_per_epoch = cur_res[1]['updates_per_epoch']
# print("dropout: %f, fisher_multiplier: %e, lr: %e" % (k[0], k[1], k[2]))
print("cur_best_avg: %e, num_updates: %d" % (cur_best_avg, cur_best_epoch))
print("best val_acc: %s" % (str(np.array(cur_res[1]['val_acc'])[:, (cur_best_epoch - 1) // tuner.eval_frequency])))
# plt.plot(cur_res['loss_with_penalty'], color='g')
# plt.plot(np.concatenate((cur_res['loss'][0][-1], cur_res['loss'][1][-1]), axis=0), color='b')
# plt.plot(np.concatenate((cur_res[0]['val_loss'][-1], cur_res[1]['val_loss'][-1]), axis=0), color='b')
# plt.show()
# plt.ylim(ymin=0.9)
plt.plot(np.concatenate((cur_res[0]['val_acc'][-1], cur_res[1]['val_acc'][-1]), axis=0), color='b')
plt.plot(np.concatenate((cur_res[0]['val_acc'][0], cur_res[1]['val_acc'][0]), axis=0), color='g')
# plt.plot(cur_res['val_acc'][1], color='g')

plt.show()

# %%
for hparam in hparams:
    hparam_tuple = tuner.hparamsDictToTuple(hparam, tuner.tuner_hparams)
    print(hparam['epsilon'], np.array(tuner.results_list[t][hparam_tuple][1]['val_acc'])[:, -1])
# Out:
# 0.0 [0.65151514 0.64999998]
# 0.1 [0.64090909 0.5       ]
# 0.2 [0.65606062 0.60000002]
# 0.4 [0.65656566 0.5       ]
# 0.5 [0.6409091  0.60000002]
# 0.7 [0.65050504 0.60000002]
# 1.0 [0.65050505 0.69999999]

# %%
# test accuracy
TEST_BATCH_SIZE = 128
test_accuracies = []
for hparam in hparams:
    accuracy = tuner.test(t, BATCH_SIZE, restore_model=True, hparams=hparam)
    test_accuracies.append(accuracy)
    print(hparam['epsilon'], accuracy)
# Out:
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1.ckpt-280
# 0.0 [0.6510101011305144, 0.46000000834465027]
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.1,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1.ckpt-280
# 0.1 [0.6477777778259431, 0.38999998569488525]
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.2,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1.ckpt-280
# 0.2 [0.6480808080326427, 0.4099999964237213]
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.4,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1.ckpt-280
# 0.4 [0.6495959594755462, 0.36000001430511475]
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.5,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1.ckpt-280
# 0.5 [0.6518181818422645, 0.4099999964237213]
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=0.7,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1.ckpt-280
# 0.7 [0.6509090909572562, 0.3700000047683716]
# INFO:tensorflow:Restoring parameters from ./checkpoints_99_1_0_distill/T=5,alpha=0.5,dropout_hidden_prob=0.9,dropout_input_prob=0.9,epsilon=1.0,learning_rate=too_long,momentum=0.9,reg=1e-05,bf_num_images=2000,mask_softmax=True,old:new=5.0,task=1.ckpt-280
# 1.0 [0.6497979797498145, 0.41999998688697815]

# %%
# Weights given to each class
num_class = 100
for i in range(num_class):
    print(i, np.sum(tuner.appended_task_list[-1].train.weights[(np.argmax(tuner.appended_task_list[-1].train.labels, axis=1) == i)]))
# Out:
# 0 0.008537709251005509
# 1 0.008655093950555082
# 2 0.008482877204380455
# 3 0.008224384955454751
# 4 0.008387565457521656
# 5 0.008682897477745968
# 6 0.008466476907745464
# 7 0.008561524361797947
# 8 0.008739389021223832
# 9 0.008341486242799484
# 10 0.008857883800945952
# 11 0.008259497093282766
# 12 0.008424734147594648
# 13 0.008293588403295506
# 14 0.0086948261616146
# 15 0.008473640914175172
# 16 0.008502468214125319
# 17 0.007729617306914627
# 18 0.008741595108047243
# 19 0.008329476711214524
# 20 0.008556082821999185
# 21 0.008201436484924043
# 22 0.008746339614711718
# 23 0.007886931102217543
# 24 0.008501038452007014
# 25 0.008638246304378046
# 26 0.008817121517966573
# 27 0.008609091426248768
# 28 0.00859612933625254
# 29 0.008605774009607034
# 30 0.00838271872273839
# 31 0.008145779325567298
# 32 0.008630240567838166
# 33 0.00792519109412509
# 34 0.008335150379537958
# 35 0.008310583340327443
# 36 0.008435426242390751
# 37 0.008205269742428557
# 38 0.008405688521830353
# 39 0.00828963160457236
# 40 0.008836938387998332
# 41 0.008561492092924408
# 42 0.008281935589191797
# 43 0.008039847911526381
# 44 0.008900621928516164
# 45 0.008729525707151728
# 46 0.008360846278168504
# 47 0.007658524649314427
# 48 0.008601436549134494
# 49 0.008031811166672679
# 50 0.008714093209331437
# 51 0.008721041188931427
# 52 0.007442991389662715
# 53 0.008425774179391459
# 54 0.008434033036504212
# 55 0.00862078414170591
# 56 0.008154475360432876
# 57 0.0086481679825469
# 58 0.008309005024975533
# 59 0.007887793373266522
# 60 0.007647972305661791
# 61 0.008965108538341565
# 62 0.008346584984024564
# 63 0.008416205209651022
# 64 0.008444179376245888
# 65 0.008671499739628837
# 66 0.00838035017832572
# 67 0.008650831813527795
# 68 0.008048247907671582
# 69 0.008221919121479754
# 70 0.008208052257016651
# 71 0.007898221041560578
# 72 0.008606463386614558
# 73 0.008560770317895093
# 74 0.008543895283193315
# 75 0.00853300491854289
# 76 0.008134404577658318
# 77 0.00877852228451929
# 78 0.00903647399343344
# 79 0.008630822688130459
# 80 0.008534172335083124
# 81 0.00817426430988547
# 82 0.008245471540176626
# 83 0.008637737903182277
# 84 0.008681312501254552
# 85 0.008442538980601705
# 86 0.008747213377226795
# 87 0.008410075642534938
# 88 0.00824438337973692
# 89 0.008359182768624882
# 90 0.008348613475628186
# 91 0.00885617672660406
# 92 0.00845072894075907
# 93 0.008782707075385015
# 94 0.007766823349936781
# 95 0.00840450974024379
# 96 0.007829711253538098
# 97 0.00830958068967413
# 98 0.008412849121292748
# 99 0.1666666745150505

# %%
old_weights = tuner.appended_task_list[1].train.weights[np.argmax(tuner.appended_task_list[1].train.labels, axis=1) != 99]
plt.rcParams['figure.figsize'] = [10, 10]
# plt.hist(old_weights)
# seaborn.distplot(old_weights)
print(old_weights.shape)
print(np.sum(old_weights < 1e-5))
print(np.sum((old_weights >= 1e-5) * (old_weights < 1e-2)))
# for i in range(1000):
#     print(w[i])

# %%
tuner.saveResultsList()
tuner.saveBestHparams()

# %%
if use_tpu:
    sess.run(tpu.shutdown_system())

sess.close()
